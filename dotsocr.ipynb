# %%
# Complete Fixed Implementation - Best Free OCR for Medical Documents
# !pip install -q easyocr paddlepaddle paddleocr torch transformers sentence-transformers faiss-cpu
# !pip install -q opencv-python pillow pandas numpy networkx matplotlib seaborn
# !apt install tesseract-ocr

import easyocr
import cv2
import numpy as np
from PIL import Image
import torch
import re
import json
from datetime import datetime
from pathlib import Path
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Setup directories
drive_root = Path('/content/drive/MyDrive')
lab_reports_dir = drive_root / 'bajaj'
prescriptions_dir = drive_root / 'prescriptions'
output_dir = Path('/content/output')
output_dir.mkdir(exist_ok=True)

print(f"Lab reports: {lab_reports_dir.exists()}")
print(f"Prescriptions: {prescriptions_dir.exists()}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 101.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.0/195.0 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 76.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.5/443.5 kB 37.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 47.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
#   Building wheel for GPUtil (setup.py) ... done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Mounted at /content/drive
# Lab reports: True
# Prescriptions: True

# %%
# !pip install verovio
# Out:
# Collecting verovio
#   Downloading verovio-5.5.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.2 kB)
# Downloading verovio-5.5.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 17.2 MB/s eta 0:00:00
# Installing collected packages: verovio
# Successfully installed verovio-5.5.0

# %%
# !pip install 'pytesseract'
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.3.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
# Robust Multi-OCR Processor - Works 100% on Colab
class RobustMedicalOCRProcessor:
    def __init__(self):
        """Initialize multiple OCR engines for maximum reliability"""
        # EasyOCR - excellent for handwritten text
        self.easy_reader = easyocr.Reader(['en'], gpu=torch.cuda.is_available())

        # Try to initialize PaddleOCR for better document structure
        try:
            from paddleocr import PaddleOCR
            # Corrected initialization - use_gpu is not a direct argument here
            self.paddle_ocr = PaddleOCR(use_angle_cls=True, lang='en')
            self.has_paddle = True
            # PaddleOCR uses a different mechanism for GPU, often set through environment or model loading
            # We will rely on the default behavior or environment setup for GPU if available.
        except ImportError:
            print("PaddleOCR not available, using EasyOCR only")
            self.paddle_ocr = None
            self.has_paddle = False
        except Exception as e:
            print(f"Error initializing PaddleOCR: {e}")
            self.paddle_ocr = None
            self.has_paddle = False


        # Tesseract as backup
        import pytesseract
        self.tesseract = pytesseract

        print("✅ Robust OCR processor initialized successfully")

    def preprocess_image(self, image_path):
        """Enhanced image preprocessing for medical documents"""
        try:
            # Load image
            image = cv2.imread(str(image_path))
            if image is None:
                return None

            # Convert to RGB
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Resize if too large (helps with processing speed)
            height, width = image_rgb.shape[:2]
            if width > 2000:
                scale = 2000 / width
                new_width = int(width * scale)
                new_height = int(height * scale)
                image_rgb = cv2.resize(image_rgb, (new_width, new_height))

            # Enhance contrast for better OCR
            lab = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2LAB)
            clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
            lab[:,:,0] = clahe.apply(lab[:,:,0])
            enhanced = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

            return enhanced

        except Exception as e:
            print(f"Preprocessing error: {e}")
            return None

    def extract_text_from_image(self, image_path, is_prescription=False):
        """Extract text using multiple OCR engines with fallback"""
        try:
            # Preprocess image
            processed_img = self.preprocess_image(image_path)
            if processed_img is None:
                return {"error": "Could not preprocess image", "text": "", "boxes": []}

            # Try EasyOCR first (best for handwritten)
            easy_text = "" # Initialize easy_text
            easy_confidence = 0.0 # Initialize easy_confidence
            try:
                easy_results = self.easy_reader.readtext(processed_img, batch_size=8, width_ths=0.8)
                easy_text = self._process_easyocr_results(easy_results)
                easy_confidence = self._calculate_easyocr_confidence(easy_results)

                # If EasyOCR gives good results, use it
                if len(easy_text.strip()) > 20 and easy_confidence > 0.4:
                    return {
                        "text": easy_text,
                        "boxes": self._format_easyocr_boxes(easy_results),
                        "confidence_score": easy_confidence,
                        "image_path": str(image_path),
                        "ocr_engine": "EasyOCR"
                    }
            except Exception as e:
                print(f"EasyOCR failed: {e}")

            # Try PaddleOCR if available
            if self.has_paddle:
                try:
                    paddle_results = self.paddle_ocr.ocr(processed_img, cls=True)
                    paddle_text = self._process_paddleocr_results(paddle_results)
                    paddle_confidence = self._calculate_paddleocr_confidence(paddle_results)

                    # If PaddleOCR gives better results, use it
                    if len(paddle_text.strip()) > len(easy_text.strip()) and paddle_confidence > 0.3:
                        return {
                            "text": paddle_text,
                            "boxes": self._format_paddleocr_boxes(paddle_results),
                            "confidence_score": paddle_confidence,
                            "image_path": str(image_path),
                            "ocr_engine": "PaddleOCR"
                        }
                except Exception as e:
                    print(f"PaddleOCR failed: {e}")

            # Fallback to Tesseract
            try:
                # Convert to grayscale for Tesseract
                gray = cv2.cvtColor(processed_img, cv2.COLOR_RGB2GRAY)
                tesseract_text = self.tesseract.image_to_string(gray, config='--psm 6')

                if len(tesseract_text.strip()) > 10:
                    return {
                        "text": tesseract_text,
                        "boxes": [],
                        "confidence_score": 0.7,
                        "image_path": str(image_path),
                        "ocr_engine": "Tesseract"
                    }
            except Exception as e:
                print(f"Tesseract failed: {e}")

            # If all OCR engines fail, return the best result we got
            return {
                "text": easy_text if 'easy_text' in locals() else "",
                "boxes": [],
                "confidence_score": easy_confidence if 'easy_confidence' in locals() else 0.0,
                "image_path": str(image_path),
                "ocr_engine": "Best Available"
            }

        except Exception as e:
            print(f"Complete OCR failure on {image_path}: {str(e)}")
            return {"error": str(e), "text": "", "boxes": []}

    def _process_easyocr_results(self, results):
        """Process EasyOCR results into text"""
        text_blocks = []
        for (bbox, text, confidence) in results:
            if confidence > 0.3 and len(text.strip()) > 0:
                text_blocks.append(text)
        return '\n'.join(text_blocks)

    def _calculate_easyocr_confidence(self, results):
        """Calculate average confidence from EasyOCR"""
        if not results:
            return 0.0
        confidences = [conf for (_, _, conf) in results if conf > 0.3]
        return sum(confidences) / len(confidences) if confidences else 0.0

    def _format_easyocr_boxes(self, results):
        """Format EasyOCR bounding boxes"""
        boxes = []
        for (bbox, text, confidence) in results:
            if confidence > 0.3:
                # Convert bbox to [x1, y1, x2, y2] format
                x_coords = [point[0] for point in bbox]
                y_coords = [point[1] for point in bbox]
                boxes.append({
                    'text': text,
                    'bbox': [min(x_coords), min(y_coords), max(x_coords), max(y_coords)],
                    'confidence': confidence
                })
        return boxes

    def _process_paddleocr_results(self, results):
        """Process PaddleOCR results into text"""
        if not results or not results[0]:
            return ""

        text_blocks = []
        for line in results[0]:
            if line:
                bbox, (text, confidence) = line # Unpack bbox and (text, confidence) tuple
                if confidence > 0.3 and len(text.strip()) > 0:
                    text_blocks.append(text)
        return '\n'.join(text_blocks)

    def _calculate_paddleocr_confidence(self, results):
        """Calculate average confidence from PaddleOCR"""
        if not results or not results[0]:
            return 0.0

        confidences = []
        for line in results[0]:
            if line:
                bbox, (text, confidence) = line # Unpack bbox and (text, confidence) tuple
                if confidence > 0.3:
                    confidences.append(confidence)
        return sum(confidences) / len(confidences) if confidences else 0.0

    def _format_paddleocr_boxes(self, results):
        """Format PaddleOCR bounding boxes"""
        if not results or not results[0]:
            return []

        boxes = []
        for line in results[0]:
            if line:
                bbox, (text, confidence) = line # Unpack bbox and (text, confidence) tuple
                if confidence > 0.3:
                    # Convert bbox to [x1, y1, x2, y2] format
                    x_coords = [point[0] for point in bbox]
                    y_coords = [point[1] for point in bbox]
                    boxes.append({
                        'text': text,
                        'bbox': [min(x_coords), min(y_coords), max(x_coords), max(y_coords)],
                        'confidence': confidence
                    })
        return boxes


# Initialize the robust OCR processor
print("🚀 Loading Robust Medical OCR Processor...")
ocr_processor = RobustMedicalOCRProcessor()
# Out:
# 🚀 Loading Robust Medical OCR Processor...
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /root/.paddlex/official_models.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('UVDoc', None)
# The model(UVDoc) is not supported to run in MKLDNN mode! Using `paddle` instead!
# Using official model (UVDoc), the model files will be automatically downloaded and saved in /root/.paddlex/official_models.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /root/.paddlex/official_models.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in /root/.paddlex/official_models.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-OCRv5_server_rec', None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in /root/.paddlex/official_models.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ✅ Robust OCR processor initialized successfully

# %%
# Enhanced Information Extraction (same as before but optimized)
class MedicalInformationExtractor:
    def __init__(self):
        # Enhanced medical patterns for better extraction
        self.medicine_patterns = [
            r'\b([A-Z][a-z]+(?:mycin|cillin|azole|pril|sartan|olol|pine|statin|formin|lol|ide))\b',
            r'\b([A-Z][a-z]+)\s+(\d+(?:\.\d+)?)\s*(mg|g|ml|mcg|units?|IU)\b',
            r'\b(Tab|Cap|Syp|Inj|Tablet|Capsule)\.?\s*([A-Z][a-z]+)\s*(\d+(?:\.\d+)?)\s*(mg|g|ml|mcg)?',
            r'\b([A-Z][a-z]+(?:\s+[A-Z][a-z]+)?)\s*[-–]\s*(\d+(?:\.\d+)?)\s*(mg|g|ml|mcg)\b',
            r'\b(Paracetamol|Aspirin|Ibuprofen|Metformin|Insulin|Amlodipine|Lisinopril|Atorvastatin|Omeprazole|Losartan)\b'
        ]

        self.lab_test_patterns = [
            r'\b(Hemoglobin|Hb|HbA1c|HBA1C|Glucose|Blood Sugar|Random Sugar|Fasting Sugar|Cholesterol|HDL|LDL|Triglycerides|Creatinine|Urea|BUN|TSH|T3|T4|FT3|FT4)\b',
            r'\b(WBC|RBC|Platelet|PLT|Hematocrit|ESR|CRP|SGPT|SGOT|ALT|AST|Bilirubin|Total Bilirubin|Direct Bilirubin)\b',
            r'\b(Sodium|Potassium|Chloride|CO2|Calcium|Phosphorus|Magnesium|Iron|Ferritin)\b',
            r'\b(Total\s+Protein|Albumin|Globulin|A/G Ratio)\b'
        ]

        self.patient_name_patterns = [
            r'(?:Patient|Name|Pt\.?|Mr\.?|Mrs\.?|Ms\.?|Miss)\s*:?\s*([A-Z][a-z]+(?:\s+[A-Z][a-z]+)+)',
            r'Name\s*:?\s*([A-Z][a-z]+(?:\s+[A-Z][a-z]+)+)',
            r'(?:^|\n)([A-Z][a-z]+\s+[A-Z][a-z]+(?:\s+[A-Z][a-z]+)?)(?:\s|$|\n)',
        ]

    def extract_from_prescription(self, ocr_result):
        """Extract structured information from prescription OCR"""
        text = ocr_result.get('text', '')

        return {
            'document_type': 'prescription',
            'patient_name': self._extract_patient_name(text),
            'date': self._extract_date(text),
            'prescriber': self._extract_prescriber(text),
            'medications': self._extract_medications(text),
            'raw_text': text,
            'confidence_score': ocr_result.get('confidence_score', 0),
            'ocr_engine': ocr_result.get('ocr_engine', 'Unknown')
        }

    def extract_from_lab_report(self, ocr_result):
        """Extract structured information from lab report OCR"""
        text = ocr_result.get('text', '')

        return {
            'document_type': 'lab_report',
            'patient_name': self._extract_patient_name(text),
            'date': self._extract_date(text),
            'lab_tests': self._extract_lab_tests(text),
            'diagnoses': self._extract_diagnoses(text),
            'raw_text': text,
            'confidence_score': ocr_result.get('confidence_score', 0),
            'ocr_engine': ocr_result.get('ocr_engine', 'Unknown')
        }

    def _extract_patient_name(self, text):
        """Extract patient name using enhanced patterns"""
        for pattern in self.patient_name_patterns:
            matches = re.finditer(pattern, text, re.MULTILINE | re.IGNORECASE)
            for match in matches:
                name = match.group(1).strip()
                if (len(name) > 3 and
                    not any(word in name.lower() for word in ['report', 'lab', 'test', 'date', 'hospital', 'clinic'])):
                    return name
        return None

    def _extract_date(self, text):
        """Extract date from text"""
        date_patterns = [
            r'(\d{1,2}[-/]\d{1,2}[-/]\d{2,4})',
            r'(\d{1,2}\s+(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*\s+\d{2,4})',
            r'(?:Date|date|Date:)\s*(\d{1,2}[-/]\d{1,2}[-/]\d{2,4})',
            r'(\d{4}[-/]\d{1,2}[-/]\d{1,2})'
        ]

        for pattern in date_patterns:
            match = re.search(pattern, text, re.IGNORECASE)
            if match:
                try:
                    date_str = match.group(1)
                    for fmt in ['%d/%m/%Y', '%d-%m-%Y', '%d %b %Y', '%d/%m/%y', '%Y-%m-%d']:
                        try:
                            return datetime.strptime(date_str, fmt).isoformat()
                        except:
                            continue
                except:
                    pass
        return None

    def _extract_prescriber(self, text):
        """Extract prescriber information"""
        patterns = [
            r'(?:Dr\.?|Doctor|Physician)\s*:?\s*([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)'
        ]

        for pattern in patterns:
            match = re.search(pattern, text, re.IGNORECASE)
            if match:
                return match.group(1).strip()
        return None

    def _extract_medications(self, text):
        """Extract medication information"""
        medications = []
        seen_names = set()

        for pattern in self.medicine_patterns:
            matches = re.finditer(pattern, text, re.IGNORECASE)
            for match in matches:
                # Handle different pattern structures
                if len(match.groups()) >= 2:
                    if match.group(0).startswith(('Tab', 'Cap', 'Syp', 'Inj')):
                        med_name = match.group(2)
                        dosage = f"{match.group(3)} {match.group(4)}" if len(match.groups()) > 3 else None
                    else:
                        med_name = match.group(1)
                        dosage = f"{match.group(2)} {match.group(3)}" if len(match.groups()) > 2 else None
                else:
                    med_name = match.group(1)
                    dosage = None

                if med_name.lower() not in seen_names:
                    medications.append({
                        'name': med_name,
                        'dosage': dosage,
                        'context': text[max(0, match.start()-50):match.end()+50].strip()
                    })
                    seen_names.add(med_name.lower())

        return medications

    def _extract_lab_tests(self, text):
        """Extract lab test results"""
        tests = []
        seen_tests = set()

        for pattern in self.lab_test_patterns:
            matches = re.finditer(pattern, text, re.IGNORECASE)
            for match in matches:
                test_name = match.group(1)

                if test_name.lower() not in seen_tests:
                    # Look for values near the test name
                    context = text[match.start():match.start()+150]
                    value_match = re.search(r'(\d+(?:\.\d+)?)\s*(mg/dl|g/dl|%|units)', context, re.IGNORECASE)

                    tests.append({
                        'test_name': test_name,
                        'value': value_match.group(1) if value_match else None,
                        'unit': value_match.group(2) if value_match else None,
                        'context': context.strip()
                    })
                    seen_tests.add(test_name.lower())

        return tests

    def _extract_diagnoses(self, text):
        """Extract diagnosis information"""
        patterns = [
            r'(?:Diagnosis|Impression|Clinical\s+Findings?|Conclusion)\s*:?\s*([A-Z][a-z]+(?:\s+[a-z]+)*)',
            r'(?:suggests?|indicates?|shows?)\s*:?\s*([A-Z][a-z]+(?:\s+[a-z]+)*)'
        ]

        diagnoses = []
        for pattern in patterns:
            matches = re.finditer(pattern, text, re.IGNORECASE)
            for match in matches:
                diagnosis = match.group(1).strip()
                if len(diagnosis) > 3:
                    diagnoses.append(diagnosis)

        return list(set(diagnoses))

# Initialize components
ie_processor = MedicalInformationExtractor()

# Knowledge Graph (same as before)
import networkx as nx

class MedicalKnowledgeGraph:
    def __init__(self):
        self.graph = nx.MultiDiGraph()
        self.node_counter = 0
        self.entity_index = defaultdict(list)

    def add_patient_record(self, extracted_data):
        patient_id = self._get_or_create_patient(extracted_data)
        document_id = self._create_document_node(extracted_data)

        self.graph.add_edge(patient_id, document_id, relation='has_document')

        if extracted_data['document_type'] == 'prescription':
            self._process_prescription_data(patient_id, document_id, extracted_data)
        elif extracted_data['document_type'] == 'lab_report':
            self._process_lab_report_data(patient_id, document_id, extracted_data)

        return patient_id, document_id

    def _get_or_create_patient(self, data):
        patient_name = data.get('patient_name') or f"Unknown_Patient_{self.node_counter}"
        existing = self.entity_index.get(f"patient_{patient_name.lower()}", [])

        if existing:
            return existing[0]

        patient_id = f"patient_{self.node_counter}"
        self.node_counter += 1

        self.graph.add_node(patient_id, type='patient', name=patient_name, created_at=datetime.now().isoformat())
        self.entity_index[f"patient_{patient_name.lower()}"].append(patient_id)
        return patient_id

    def _create_document_node(self, data):
        doc_id = f"doc_{self.node_counter}"
        self.node_counter += 1

        self.graph.add_node(doc_id, type='document', document_type=data['document_type'],
                           date=data.get('date'), raw_text=data.get('raw_text', ''),
                           confidence=data.get('confidence_score', 0),
                           ocr_engine=data.get('ocr_engine', 'Unknown'))
        return doc_id

    def _process_prescription_data(self, patient_id, doc_id, data):
        prescription_id = f"prescription_{self.node_counter}"
        self.node_counter += 1

        self.graph.add_node(prescription_id, type='prescription', date=data.get('date'),
                           prescriber=data.get('prescriber'))

        self.graph.add_edge(patient_id, prescription_id, relation='has_prescription')
        self.graph.add_edge(doc_id, prescription_id, relation='contains_prescription')

        for med in data.get('medications', []):
            med_id = self._get_or_create_medication(med['name'])
            self.graph.add_edge(prescription_id, med_id, relation='prescribes',
                              dosage=med.get('dosage'))

    def _process_lab_report_data(self, patient_id, doc_id, data):
        encounter_id = f"encounter_{self.node_counter}"
        self.node_counter += 1

        self.graph.add_node(encounter_id, type='encounter', date=data.get('date'))
        self.graph.add_edge(patient_id, encounter_id, relation='has_encounter')
        self.graph.add_edge(doc_id, encounter_id, relation='documents_encounter')

        for test in data.get('lab_tests', []):
            test_id = self._get_or_create_lab_test(test['test_name'])
            result_id = f"result_{self.node_counter}"
            self.node_counter += 1

            self.graph.add_node(result_id, type='lab_result', value=test.get('value'),
                               unit=test.get('unit'), date=data.get('date'))

            self.graph.add_edge(encounter_id, result_id, relation='has_result')
            self.graph.add_edge(result_id, test_id, relation='result_of_test')

    def _get_or_create_medication(self, med_name):
        key = f"medication_{med_name.lower()}"
        existing = self.entity_index.get(key, [])
        if existing:
            return existing[0]

        med_id = f"medication_{self.node_counter}"
        self.node_counter += 1
        self.graph.add_node(med_id, type='medication', name=med_name)
        self.entity_index[key].append(med_id)
        return med_id

    def _get_or_create_lab_test(self, test_name):
        key = f"lab_test_{test_name.lower()}"
        existing = self.entity_index.get(key, [])
        if existing:
            return existing[0]

        test_id = f"lab_test_{self.node_counter}"
        self.node_counter += 1
        self.graph.add_node(test_id, type='lab_test', name=test_name)
        self.entity_index[key].append(test_id)
        return test_id

    def query_medication_patterns(self):
        patterns = defaultdict(int)
        prescription_nodes = [n for n, d in self.graph.nodes(data=True) if d.get('type') == 'prescription']

        for prescription_id in prescription_nodes:
            for neighbor in self.graph.successors(prescription_id):
                node_data = self.graph.nodes[neighbor]
                if node_data.get('type') == 'medication':
                    patterns[node_data.get('name')] += 1

        sorted_patterns = sorted(patterns.items(), key=lambda x: x[1], reverse=True)
        return {'common_medications': sorted_patterns[:10], 'total_prescriptions': len(prescription_nodes)}

# Initialize Knowledge Graph
kg = MedicalKnowledgeGraph()

# %%
# Main Processing Pipeline - FIXED VERSION
def process_medical_documents_robust():
    """Process all medical documents using robust OCR with proper error handling"""
    processed_documents = []

    print("🔍 Processing Lab Reports with Robust OCR...")

    # Get lab report files
    lab_files = []
    if lab_reports_dir.exists():
        lab_files = (list(lab_reports_dir.rglob('*.png')) +
                    list(lab_reports_dir.rglob('*.jpg')) +
                    list(lab_reports_dir.rglob('*.jpeg')))

    print(f"Found {len(lab_files)} lab report files")

    # Process all lab reports
    success_count = 0
    for i, img_path in enumerate(lab_files):
        print(f"Processing lab report {i+1}/{len(lab_files)}: {img_path.name}")

        try:
            # Use robust OCR
            ocr_result = ocr_processor.extract_text_from_image(img_path, is_prescription=False)

            if ocr_result.get('text') and len(ocr_result['text'].strip()) > 20:
                # Information Extraction
                extracted_data = ie_processor.extract_from_lab_report(ocr_result)
                extracted_data['image_path'] = str(img_path)

                # Add to Knowledge Graph
                patient_id, doc_id = kg.add_patient_record(extracted_data)
                extracted_data['patient_id'] = patient_id
                extracted_data['doc_id'] = doc_id

                processed_documents.append(extracted_data)
                success_count += 1

                print(f"✅ SUCCESS: Patient={extracted_data.get('patient_name', 'Unknown')}, "
                      f"Tests={len(extracted_data.get('lab_tests', []))}, "
                      f"Engine={extracted_data.get('ocr_engine', 'Unknown')}")
            else:
                print(f"❌ No meaningful text extracted from {img_path.name}")

        except Exception as e:
            print(f"❌ Error processing {img_path.name}: {str(e)}")
            continue

    print(f"\n📊 Lab Reports: {success_count}/{len(lab_files)} processed successfully")

    print(f"\n🔍 Processing Prescription Images...")

    # Get prescription files
    prescription_files = []
    if prescriptions_dir.exists():
        prescription_files = (list(prescriptions_dir.rglob('*.png')) +
                             list(prescriptions_dir.rglob('*.jpg')) +
                             list(prescriptions_dir.rglob('*.jpeg')))

    print(f"Found {len(prescription_files)} prescription files")

    # Process all prescriptions
    prescription_success = 0
    for i, img_path in enumerate(prescription_files):
        print(f"Processing prescription {i+1}/{len(prescription_files)}: {img_path.name}")

        try:
            # Use robust OCR
            ocr_result = ocr_processor.extract_text_from_image(img_path, is_prescription=True)

            if ocr_result.get('text') and len(ocr_result['text'].strip()) > 20:
                # Information Extraction
                extracted_data = ie_processor.extract_from_prescription(ocr_result)
                extracted_data['image_path'] = str(img_path)

                # Add to Knowledge Graph
                patient_id, doc_id = kg.add_patient_record(extracted_data)
                extracted_data['patient_id'] = patient_id
                extracted_data['doc_id'] = doc_id

                processed_documents.append(extracted_data)
                prescription_success += 1

                print(f"✅ SUCCESS: Patient={extracted_data.get('patient_name', 'Unknown')}, "
                      f"Meds={len(extracted_data.get('medications', []))}, "
                      f"Engine={extracted_data.get('ocr_engine', 'Unknown')}")
            else:
                print(f"❌ No meaningful text extracted from {img_path.name}")

        except Exception as e:
            print(f"❌ Error processing {img_path.name}: {str(e)}")
            continue

    print(f"\n📊 Prescriptions: {prescription_success}/{len(prescription_files)} processed successfully")

    return processed_documents

# Run the fixed processing pipeline
print("🚀 Starting FIXED Medical Document Processing...")
processed_docs = process_medical_documents_robust()

print(f"\n📊 FINAL PROCESSING SUMMARY:")
print(f"Total documents processed: {len(processed_docs)}")
print(f"Lab reports: {sum(1 for doc in processed_docs if doc['document_type'] == 'lab_report')}")
print(f"Prescriptions: {sum(1 for doc in processed_docs if doc['document_type'] == 'prescription')}")

if processed_docs:
    print(f"Knowledge graph nodes: {kg.graph.number_of_nodes()}")
    print(f"Knowledge graph edges: {kg.graph.number_of_edges()}")

    # Show OCR engine statistics
    engine_stats = defaultdict(int)
    for doc in processed_docs:
        engine_stats[doc.get('ocr_engine', 'Unknown')] += 1

    print(f"\n🔧 OCR Engine Usage:")
    for engine, count in engine_stats.items():
        print(f"  {engine}: {count} documents")

    # Save results
    with open('/content/output/processed_documents_robust.json', 'w') as f:
        json.dump(processed_docs, f, indent=2, default=str)

    print(f"\n💾 Documents saved to: /content/output/processed_documents_robust.json")
    print("✅ ROBUST MEDICAL RAG SYSTEM READY!")
else:
    print("❌ No documents were processed successfully. Check your image files and directory paths.")
# Out:
# 🚀 Starting FIXED Medical Document Processing...
# 🔍 Processing Lab Reports with Robust OCR...
# Found 426 lab report files
# Processing lab report 1/426: BLR-0425-PA-0037318_SASHANK P K 0037318 2 OF 2_28-04-2025_1007-19_AM@E.pdf_page_29.png
# ✅ SUCCESS: Patient=UHID
# AIGG, Tests=0, Engine=EasyOCR
# Processing lab report 2/426: BLR-0425-PA-0039192_E-ParmeshwarRunningBill_250426_1612@E.pdf_page_93.png
# ✅ SUCCESS: Patient=ID
# Patient, Tests=0, Engine=EasyOCR
# Processing lab report 3/426: BLR-0425-PA-0037318_SASHANK P K 0037318 2 OF 2_28-04-2025_1007-19_AM@E.pdf_page_33.png
# ✅ SUCCESS: Patient=UHID
# AIGG, Tests=0, Engine=EasyOCR
# Processing lab report 4/426: BLR-0425-PA-0038965_BIPUL CHAKRABORTY 0038965 2 OF 2_28-04-2025_1014-26_AM.pdf_page_16.png
# ✅ SUCCESS: Patient=WITH INR AND APTT
# Ctared Piasttx, Tests=0, Engine=EasyOCR
# Processing lab report 5/426: AHD-0425-PA-0007719_E-REPORTS_250427_2032@E.pdf_page_7.png
# ✅ SUCCESS: Patient=FULLY
# DIAGnOSTIC
# COMPUTERISED, Tests=5, Engine=EasyOCR
# Processing lab report 6/426: BLR-0425-PA-0039192_E-PareshwarFinalBill_250427_1337@E.pdf_page_99.png
# ✅ SUCCESS: Patient=Diagnostic Point Pathology, Tests=1, Engine=EasyOCR
# Processing lab report 7/426: BLR-0425-PA-0039192_E-PareshwarFinalBill_250427_1337@E.pdf_page_88.png
# ✅ SUCCESS: Patient=Referred
# VERMA
# Receiving, Tests=0, Engine=EasyOCR
# Processing lab report 8/426: BLR-0425-PA-0039192_05c45741fa5d4b5180df06f200423a00__2_files_merged__26-04-2025_0430-01_PM@E.pdf_page_104.png
# ✅ SUCCESS: Patient=ID
# Patient, Tests=6, Engine=EasyOCR
# Processing lab report 9/426: BLR-0425-PA-0037318_SASHANK P K 0037318 2 OF 2_28-04-2025_1007-19_AM@E.pdf_page_20.png
# ✅ SUCCESS: Patient=UHID
# AIGG, Tests=3, Engine=EasyOCR
# Processing lab report 10/426: BLR-0425-PA-0038965_BIPUL CHAKRABORTY 0038965 2 OF 2_28-04-2025_1014-26_AM.pdf_page_7.png
# ✅ SUCCESS: Patient=orns   is
# Random   plasma   glucoso
# Interprelations, Tests=2, Engine=EasyOCR
# Processing lab report 11/426: BLR-0425-PA-0037318_SASHANK P K 0037318 2 OF 2_28-04-2025_1007-19_AM@E.pdf_page_31.png
# ✅ SUCCESS: Patient=UHID
# AIGG, Tests=0, Engine=EasyOCR
# Processing lab report 12/426: BLR-0425-PA-0036693_ARVIND REDDY REPALA 0036693_28-04-2025_1120-45_AM@E.pdf_page_24.png
# ✅ SUCCESS: Patient=Episode
# IP, Tests=3, Engine=EasyOCR
# Processing lab report 13/426: AHD-0425-PA-0008061_E-mahendrasinghdischargecard_250427_1114@E.pdf_page_27.png
# ✅ SUCCESS: Patient=SHREE DIAGNOSTIC
# Near, Tests=5, Engine=EasyOCR
# Processing lab report 14/426: AHD-0425-PA-0007561_JITENDRA TRIVEDI DS_28-04-2025_1019-21_AM.pdf_page_9.png
# ✅ SUCCESS: Patient=PLATELET INDICES, Tests=5, Engine=EasyOCR
# Processing lab report 15/426: AHD-0425-PA-0008061_E-mahendrasinghdischargecard_250427_1114@E.pdf_page_13.png
# ✅ SUCCESS: Patient=Near Shivaji Maharaj, Tests=3, Engine=EasyOCR
# Processing lab report 16/426: BLR-0425-PA-0038965_BIPUL CHAKRABORTY 0038965 2 OF 2_28-04-2025_1014-26_AM.pdf_page_8.png
# ✅ SUCCESS: Patient=Name
# Mr, Tests=1, Engine=EasyOCR
# Processing lab report 17/426: AHD-0425-PA-0007719_E-REPORTS_250427_2032@E.pdf_page_4.png
# ✅ SUCCESS: Patient=FULLY
# COMPUTERISED
# PATHOLOGICAL, Tests=1, Engine=EasyOCR
# Processing lab report 18/426: BLR-0425-PA-0040301_Q-Report3_250422_1436@F.pdf_page_2.png
# ✅ SUCCESS: Patient=ical Clot Detection
# Method
# Prothrombin Time, Tests=7, Engine=EasyOCR
# Processing lab report 19/426: BLR-0425-PA-0041313_F-sudhirpreauth_250424_1309@G.pdf_page_14.png
# ✅ SUCCESS: Patient=First
# HAEMATOLOGY
# Result No, Tests=4, Engine=EasyOCR
# Processing lab report 20/426: BLR-0425-PA-0041374_E-REPORT_250427_1413@E.pdf_page_2.png
# ✅ SUCCESS: Patient=IPDNo
# Dr, Tests=3, Engine=EasyOCR
# Processing lab report 21/426: BLR-0425-PA-0040749_G RAJU_27-04-2025_1103-55_PM.pdf_page_35.png
# ✅ SUCCESS: Patient=No
# Sample Rec, Tests=0, Engine=EasyOCR
# Processing lab report 22/426: BLR-0425-PA-0041171_MEKHA LAMBA STAY LETTER_26-04-2025_0253-30_PM@E.pdf_page_24.png
# ✅ SUCCESS: Patient=spost
# IFN, Tests=0, Engine=EasyOCR
# Processing lab report 23/426: BLR-0425-PA-0039192_a044492e47444b7ca0f3e3bbe049ce2c_compressed_27-04-2025_0228-52_PM@E.pdf_page_76.png
# ✅ SUCCESS: Patient=Diagnostic Point Pathology, Tests=6, Engine=EasyOCR
# Processing lab report 24/426: BLR-0425-PA-0040652_LAB MERG_27-04-2025_1239-18_PM@E.pdf_page_7.png
# ✅ SUCCESS: Patient=Srivalli
# Good Life, Tests=1, Engine=EasyOCR
# Processing lab report 25/426: BLR-0425-PA-0040652_LAB MERG_27-04-2025_1239-18_PM@E.pdf_page_2.png
# ✅ SUCCESS: Patient=Srivalli
# Good Life, Tests=10, Engine=EasyOCR
# Processing lab report 26/426: BLR-0425-PA-0040880_E-1745741621426SUSHILADEVIds_250427_1347@E.pdf_page_2.png
# ✅ SUCCESS: Patient=GASTROENTEROLOGY
# Department
# Admitted, Tests=7, Engine=EasyOCR
# Processing lab report 27/426: BLR-0425-PA-0039883_ALL CLAIMS DOCM BHUVANESHWARI VIDAL_0001_27-04-2025_1131-10_AM@E.pdf_page_38.png
# ✅ SUCCESS: Patient=Order No
# ELECTROLYTES, Tests=4, Engine=EasyOCR
# Processing lab report 28/426: BLR-0425-PA-0041078_D CARD AND REPORT_11zon_27-04-2025_1204-56_PM.pdf_page_8.png
# ✅ SUCCESS: Patient=MOHD UVAIS
# NASHD
# Wwaskapollo com
# FIFTHFLOOR, Tests=1, Engine=EasyOCR
# Processing lab report 29/426: BLR-0425-PA-0039320_501848074 Final bill and DS   26042025_27-04-2025_1054-20_AM.pdf_page_10.png
# ✅ SUCCESS: Patient=We Il Treat, Tests=4, Engine=EasyOCR
# Processing lab report 30/426: BLR-0425-PA-0040761_BLR0425PA0040761 TURYA KULAKRNI   INVESTIGATION REPORTS_27-04-2025_0633-05_PM@G.pdf_page_3.png
# ✅ SUCCESS: Patient=imal
# Sample is Non, Tests=0, Engine=EasyOCR
# Processing lab report 31/426: BLR-0425-PA-0040326_Lab Report Sunita_27-04-2025_0131-15_PM@G.pdf_page_11.png
# ✅ SUCCESS: Patient=TRY
# LFT, Tests=10, Engine=EasyOCR
# Processing lab report 32/426: BLR-0425-PA-0039930_E-BABY_OF_SIREESHA_BADVELU_2_250427_1048@E.pdf_page_8.png
# ✅ SUCCESS: Patient=SIRREEESHA
# Dr, Tests=0, Engine=EasyOCR
# Processing lab report 33/426: BLR-0425-PA-0040749_F-RAJU_GODUGULA_1_250422_1924@G.pdf_page_24.png
# ✅ SUCCESS: Patient=ion of septic infection is accompanied
# by decreases in PCT concentration which
# returns to normal with half life of, Tests=9, Engine=EasyOCR
# Processing lab report 34/426: BLR-0425-PA-0041577_PA REQUEST_24-04-2025_0744-39_PM@G.pdf_page_15.png
# ✅ SUCCESS: Patient=ION
# RESULT
# REFEERENCE WNTERVAL
# Colour, Tests=3, Engine=EasyOCR
# Processing lab report 35/426: BLR-0425-PA-0041109_F-PREAUTH202504230003_250423_1752@G.pdf_page_7.png
# ✅ SUCCESS: Patient=ION
# RESULT
# UNITS, Tests=3, Engine=EasyOCR
# Processing lab report 36/426: BLR-0425-PA-0040749_G RAJU_27-04-2025_1103-55_PM.pdf_page_42.png
# ✅ SUCCESS: Patient=NARH
# DEPARTMENT OF, Tests=0, Engine=EasyOCR
# Processing lab report 37/426: BLR-0425-PA-0039883_ALL CLAIMS DOCM BHUVANESHWARI VIDAL_0001_27-04-2025_1131-10_AM@E.pdf_page_41.png
# ✅ SUCCESS: Patient=Order No
# Others, Tests=0, Engine=EasyOCR
# Processing lab report 38/426: BLR-0425-PA-0039930_E-BABY_OF_SIREESHA_BADVELU_2_250427_1048@E.pdf_page_11.png
# ✅ SUCCESS: Patient=SIRREEESHA
# Dr, Tests=1, Engine=EasyOCR
# Processing lab report 39/426: BLR-0425-PA-0042567_F-RAJEEVPREAUTH_250427_1441@G.pdf_page_16.png
# ✅ SUCCESS: Patient=Nandha Kumar, Tests=0, Engine=EasyOCR
# Processing lab report 40/426: BLR-0425-PA-0042563_Q-1745819430717VasanthaKumarilab_250428_1123@F.pdf_page_1.png
# ✅ SUCCESS: Patient=Print Results, Tests=5, Engine=EasyOCR
# Processing lab report 41/426: BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905cf4d4a1_27-04-2025_0520-51_PM@E.pdf_page_14.png
# ✅ SUCCESS: Patient=By
# Dr VIVEK, Tests=4, Engine=EasyOCR
# Processing lab report 42/426: BLR-0425-PA-0041660_KAUSHAL_REPORTS_26-04-2025_0822-20_PM@F.pdf_page_6.png
# ✅ SUCCESS: Patient=Result
# Unit
# Biological Reference
# Blood, Tests=1, Engine=EasyOCR
# Processing lab report 43/426: BLR-0425-PA-0042494_Malathi_Sudheendra_LAB_26-04-2025_0923-40_PM@G.pdf_page_4.png
# ✅ SUCCESS: Patient=WA
# MBM
# NEPHROLOGY, Tests=8, Engine=EasyOCR
# Processing lab report 44/426: BLR-0425-PA-0042483_Q-CamScanner0428202511.39_250428_1144@F.pdf_page_8.png
# ✅ SUCCESS: Patient=Samplo Colloctod At, Tests=2, Engine=EasyOCR
# Processing lab report 45/426: BLR-0425-PA-0041660_KAUSHAL REPORTS_27-04-2025_0924-48_AM.pdf_page_11.png
# ✅ SUCCESS: Patient=ical clot detection, Tests=1, Engine=EasyOCR
# Processing lab report 46/426: BLR-0425-PA-0042578_F-1745748343928ICPNOTESOFJAYALAKSHMI_250427_1542@G.pdf_page_11.png
# ✅ SUCCESS: Patient=IPDE
# Tet Rcport, Tests=6, Engine=EasyOCR
# Processing lab report 47/426: BLR-0425-PA-0041591_DISCHARGE_0001_27-04-2025_0313-06_PM.pdf_page_8.png
# ✅ SUCCESS: Patient=PTI
# Control, Tests=0, Engine=EasyOCR
# Processing lab report 48/426: BLR-0425-PA-0042521_F-1745734178007ICPNOTESOFPRASANNAKUMAR_250427_1146@G.pdf_page_16.png
# ✅ SUCCESS: Patient=ID
# FH, Tests=1, Engine=EasyOCR
# Processing lab report 49/426: BLR-0425-PA-0042483_F-CamScanner0426202520.02_250426_2031@G.pdf_page_20.png
# ✅ SUCCESS: Patient=Damnpla Collactod, Tests=3, Engine=EasyOCR
# Processing lab report 50/426: BLR-0425-PA-0042347_Mayuri_salve_pt_preaurth_form_26-04-2025_0411-17_PM@G.pdf_page_20.png
# ✅ SUCCESS: Patient=ASHRAYA Diagnosticsk
# Ashraya, Tests=4, Engine=EasyOCR
# Processing lab report 51/426: BLR-0425-PA-0042579_F-SARAFATHIMAPREAUTHREQUEST_250427_1545@G.pdf_page_11.png
# ✅ SUCCESS: Patient=SUNITA SISTER
# MCROBIQLOGY
# NON, Tests=0, Engine=EasyOCR
# Processing lab report 52/426: BLR-0425-PA-0042494_Malathi_Sudheendra_LAB_26-04-2025_0923-40_PM@G.pdf_page_3.png
# ✅ SUCCESS: Patient=RBC   COUNT, Tests=7, Engine=EasyOCR
# Processing lab report 53/426: BLR-0425-PA-0041660_KAUSHAL REPORTS_27-04-2025_0924-48_AM@E.pdf_page_8.png
# ✅ SUCCESS: Patient=Mayur Rai
# Order, Tests=4, Engine=EasyOCR
# Processing lab report 54/426: BLR-0425-PA-0042555_F-KYC_PC_VAMSI_MOHANA_JAKKINAPALLI_1_250427_1354@G.pdf_page_18.png
# ✅ SUCCESS: Patient=ION
# Colour, Tests=4, Engine=EasyOCR
# Processing lab report 55/426: BLR-0425-PA-0042255_E-SITAMAHALAKSHMI_KATTA_2_250427_1224@E.pdf_page_5.png
# ✅ SUCCESS: Patient=COMPLETE URINE EXAMINATION
# Normal Range
# Parameter
# Result
# COLOUR
# Pale yellow
# Pale yellow
# UROBILINOGEN
# Normal
# Negative
# Negative
# BLOOD
# Negative
# Negative
# NITRITE
# null
# Negative
# Negative
# LEUCOCYTE, Tests=4, Engine=EasyOCR
# Processing lab report 56/426: BLR-0425-PA-0041660_KAUSHAL REPORTS_27-04-2025_1009-13_AM@E.pdf_page_10.png
# ✅ SUCCESS: Patient=MATRIX WEST
# Registered, Tests=2, Engine=EasyOCR
# Processing lab report 57/426: BLR-0425-PA-0041660_KAUSHAL_REPORTS_26-04-2025_0822-20_PM@F.pdf_page_9.png
# ✅ SUCCESS: Patient=ical clot detection, Tests=1, Engine=EasyOCR
# Processing lab report 58/426: BLR-0425-PA-0041660_KAUSHAL REPORTS_26-04-2025_1047-39_PM@F.pdf_page_9.png
# ✅ SUCCESS: Patient=ical clot detection, Tests=1, Engine=EasyOCR
# Processing lab report 59/426: BLR-0425-PA-0042674_F-HALEEMALAB28_250428_1048@G.pdf_page_10.png
# ✅ SUCCESS: Patient=IPD
# Patient ID, Tests=1, Engine=EasyOCR
# Processing lab report 60/426: BLR-0425-PA-0042659_REPORT_0001_28-04-2025_1015-20_AM@G.pdf_page_10.png
# ✅ SUCCESS: Patient=DEPARTMENT OF PATHOLOGY, Tests=3, Engine=EasyOCR
# Processing lab report 61/426: BLR-0425-PA-0042625_F-PREAUTHREQUEST_250427_1911@G.pdf_page_11.png
# ✅ SUCCESS: Patient=PAEDIATRIC CHART
# INDOOR, Tests=0, Engine=EasyOCR
# Processing lab report 62/426: BLR-0425-PA-0042583_F-1745749507807ICPNOTESOFCHUNCHAIAH2_250427_1601@G.pdf_page_8.png
# ✅ SUCCESS: Patient=Vest Rcport status, Tests=0, Engine=EasyOCR
# Processing lab report 63/426: CHE-0425-PA-0013491_E-LABREPORT_250428_1031@E.pdf_page_4.png
# ✅ SUCCESS: Patient=Sample No, Tests=2, Engine=EasyOCR
# Processing lab report 64/426: BLR-0425-PA-0042670_F-NiyaAdwithaQueryReplied_250428_1045@G.pdf_page_6.png
# ✅ SUCCESS: Patient=KANCHI KAMAKOTI CHILDS, Tests=0, Engine=EasyOCR
# Processing lab report 65/426: CHD-0425-PA-0009734_rr_27-04-2025_0153-00_PM@G.pdf_page_5.png
# ✅ SUCCESS: Patient=Admn
# No, Tests=2, Engine=EasyOCR
# Processing lab report 66/426: BLR-0425-PA-0042585_F-RARI_S_MANIKANDAN_1_250427_1609@G.pdf_page_37.png
# ✅ SUCCESS: Patient=Patientl
# Sample Type, Tests=3, Engine=EasyOCR
# Processing lab report 67/426: BLR-0425-PA-0042594_F-BABYOFSSIRISHAICP_250427_1634@G.pdf_page_13.png
# ✅ SUCCESS: Patient=Name
# BirthRighe, Tests=10, Engine=EasyOCR
# Processing lab report 68/426: CHD-0425-PA-0009736_F-JANAKRANI_250427_1826@G.pdf_page_6.png
# ✅ SUCCESS: Patient=ISHITA
# SHOOR
# IE, Tests=9, Engine=EasyOCR
# Processing lab report 69/426: BLR-0425-PA-0042650_F-SHWETAPA_250428_0922@G.pdf_page_18.png
# ✅ SUCCESS: Patient=MRN
# Collected On, Tests=0, Engine=EasyOCR
# Processing lab report 70/426: BLR-0425-PA-0042598_Q-bgh20250427165405127229018626_250427_1656@F.pdf_page_28.png
# ✅ SUCCESS: Patient=ive diagnosis of Mycobacterial disease, Tests=0, Engine=EasyOCR
# Processing lab report 71/426: CHE-0325-PA-0010741_AL REPORTS_25-04-2025_0346-49_PM@F.pdf_page_8.png
# ✅ SUCCESS: Patient=for error, Tests=4, Engine=EasyOCR
# Processing lab report 72/426: CHD-0425-PA-0008729_REQUEST FOR ENHACEMENT_28-04-2025_1006-46_AM.pdf_page_13.png
# ✅ SUCCESS: Patient=Sample No, Tests=1, Engine=EasyOCR
# Processing lab report 73/426: BLR-0425-PA-0042659_REPORT_0001_28-04-2025_1015-20_AM@G.pdf_page_7.png
# ✅ SUCCESS: Patient=DEPARTMENT OF PATHOLOGY, Tests=3, Engine=EasyOCR
# Processing lab report 74/426: BLR-0425-PA-0042614_F-KYC_PC_BARNISH_ARULMOZHIE_1_250427_1745@G.pdf_page_8.png
# ✅ SUCCESS: Patient=Print Results
# Dr, Tests=8, Engine=EasyOCR
# Processing lab report 75/426: CHE-0425-PA-0013118_E-FBANDS_250427_1234@E.pdf_page_28.png
# ✅ SUCCESS: Patient=THE MADRAS MEDICAL, Tests=0, Engine=EasyOCR
# Processing lab report 76/426: CHD-0425-PA-0008729_REQUEST FOR ENHACEMENT_27-04-2025_1049-52_AM.pdf_page_12.png
# ✅ SUCCESS: Patient=Hero Cycles, Tests=3, Engine=EasyOCR
# Processing lab report 77/426: CHE-0425-PA-0012251_Q-1745740582093MNJUQR_250427_1329@F.pdf_page_62.png
# ✅ SUCCESS: Patient=Supp
# pTv
# Tioz, Tests=0, Engine=EasyOCR
# Processing lab report 78/426: CHE-0325-PA-0010741_AL REPORTS_28-04-2025_1147-05_AM@E.pdf_page_8.png
# ✅ SUCCESS: Patient=for error, Tests=4, Engine=EasyOCR
# Processing lab report 79/426: CHD-0425-PA-0008729_REQUEST FOR ENHACEMENT_28-04-2025_1006-46_AM.pdf_page_14.png
# ✅ SUCCESS: Patient=FINDING
# NORMAL RANGE, Tests=6, Engine=EasyOCR
# Processing lab report 80/426: BLR-0425-PA-0042618_F-1745754894410SUBRAMANILAB_250427_1816@G.pdf_page_3.png
# ✅ SUCCESS: Patient=or third party, Tests=17, Engine=EasyOCR
# Processing lab report 81/426: CHE-0425-PA-0013889_ALL CLAIMS DOCM HARIPRIYA VIDAL_0001_27-04-2025_1124-43_AM.pdf_page_23.png
# ✅ SUCCESS: Patient=Order No, Tests=3, Engine=EasyOCR
# Processing lab report 82/426: CHE-0425-PA-0013293_E-1745731046905VIJAYLAKSHMIDS_250427_1050@E.pdf_page_7.png
# ✅ SUCCESS: Patient=Platelet Count, Tests=4, Engine=EasyOCR
# Processing lab report 83/426: CHE-0425-PA-0014111_SOORYA PRAKASH INVESTIGATIONS_compressed_27-04-2025_0130-33_PM.pdf_page_13.png
# ✅ SUCCESS: Patient=ical Clot detection
# Note, Tests=0, Engine=EasyOCR
# Processing lab report 84/426: CHE-0425-PA-0014202_E-BLOODREPORTPREMA_250428_0045@E.pdf_page_2.png
# ✅ SUCCESS: Patient=ID
# SID NO, Tests=0, Engine=EasyOCR
# Processing lab report 85/426: CHE-0425-PA-0013990_E-DischargeSummary_250427_1530@E.pdf_page_3.png
# ✅ SUCCESS: Patient=OOM NO, Tests=7, Engine=EasyOCR
# Processing lab report 86/426: CHE-0425-PA-0014256_Doc Apr 27 2025 16.08_27-04-2025_0418-53_PM.pdf_page_19.png
# ✅ SUCCESS: Patient=Female
# Patlont
# Gender, Tests=6, Engine=EasyOCR
# Processing lab report 87/426: CHE-0425-PA-0014450_F-ASHOKLAB_250427_1146@G.pdf_page_2.png
# ✅ SUCCESS: Patient=Referred By
# TEJAS, Tests=1, Engine=EasyOCR
# Processing lab report 88/426: CHE-0425-PA-0014100_KALIAMMAL RECONSIDER REQUEST_28-04-2025_0951-48_AM@F.pdf_page_8.png
# ✅ SUCCESS: Patient=DEPARTMENT OF BIOCHEMISTRY, Tests=1, Engine=EasyOCR
# Processing lab report 89/426: CHE-0425-PA-0013910_F-MR._TANUJ_JAIN_1_250423_1230@G.pdf_page_21.png
# ✅ SUCCESS: Patient=ed on
# Dr RV, Tests=0, Engine=EasyOCR
# Processing lab report 90/426: CHE-0425-PA-0014111_QUERY REPLY  MR.SOORYA PRAKASH_27-04-2025_0130-33_PM.pdf_page_2.png
# ✅ SUCCESS: Patient=No
# CRP, Tests=14, Engine=EasyOCR
# Processing lab report 91/426: CHE-0425-PA-0014385_E-INDOORCASEPAPER_250428_1152@E.pdf_page_31.png
# ✅ SUCCESS: Patient=ion
# Specimen
# BOGHEMISTRY, Tests=2, Engine=EasyOCR
# Processing lab report 92/426: CHE-0425-PA-0014111_SOORYA PRAKASH INVESTIGATIONS_compressed_27-04-2025_0130-33_PM.pdf_page_5.png
# ✅ SUCCESS: Patient=Neuberg
# DAGNostic, Tests=5, Engine=EasyOCR
# Processing lab report 93/426: CHE-0425-PA-0014111_SOORYA PRAKASH INVESTIGATIONS_compressed_27-04-2025_0130-33_PM@F.pdf_page_5.png
# ✅ SUCCESS: Patient=Neuberg
# DAGNostic, Tests=5, Engine=EasyOCR
# Processing lab report 94/426: CHE-0425-PA-0014457_Q-SaraswathiQueryreply_250428_1139@F.pdf_page_14.png
# ✅ SUCCESS: Patient=Rogyl
# Unk
# Medl Pack, Tests=3, Engine=EasyOCR
# Processing lab report 95/426: COM-0425-PA-0017017_COM0425PA0017017 fb_27-04-2025_1216-45_PM@E.pdf_page_15.png
# ✅ SUCCESS: Patient=TRY
# SUGAR, Tests=2, Engine=EasyOCR
# Processing lab report 96/426: CHE-0425-PA-0014100_KALIAMMAL RECONSIDER REQUEST_27-04-2025_0931-54_AM@F.pdf_page_10.png
# ✅ SUCCESS: Patient=DEPARTMENT OF BIOCHEMISTRY, Tests=1, Engine=EasyOCR
# Processing lab report 97/426: CHE-0425-PA-0014100_KALIAMMAL RECONSIDER REQUEST_28-04-2025_1125-47_AM@F.pdf_page_4.png
# ✅ SUCCESS: Patient=Female
# Mrs, Tests=0, Engine=EasyOCR
# Processing lab report 98/426: CHE-0425-PA-0014457_Q-SaraswathiQueryreply_250428_1139@F.pdf_page_12.png
# ✅ SUCCESS: Patient=Result
# CBC, Tests=2, Engine=EasyOCR
# Processing lab report 99/426: CHE-0425-PA-0014115_Q-Chandruquery_250427_1853@F.pdf_page_33.png
# ✅ SUCCESS: Patient=ID
# UHID, Tests=6, Engine=EasyOCR
# Processing lab report 100/426: CHE-0425-PA-0014100_KALIAMMAL RECONSIDER REQUEST_28-04-2025_1125-47_AM@F.pdf_page_7.png
# ✅ SUCCESS: Patient=DEPARTMENT OF HAEMATOLOGY, Tests=2, Engine=EasyOCR
# Processing lab report 101/426: CHE-0425-PA-0014111_SOORYA PRAKASH INVESTIGATIONS_compressed_27-04-2025_0130-33_PM.pdf_page_16.png
# ✅ SUCCESS: Patient=omatic Hepatitis, Tests=0, Engine=EasyOCR
# Processing lab report 102/426: CHE-0425-PA-0013990_Final Reports_27-04-2025_0256-06_PM.pdf_page_2.png
# ✅ SUCCESS: Patient=ed on, Tests=3, Engine=EasyOCR
# Processing lab report 103/426: CHE-0425-PA-0014385_E-INDOORCASEPAPER_250428_1152@E.pdf_page_40.png
# ✅ SUCCESS: Patient=MK
# No, Tests=12, Engine=EasyOCR
# Processing lab report 104/426: CHE-0425-PA-0013990_Final Reports_27-04-2025_0256-06_PM.pdf_page_5.png
# ✅ SUCCESS: Patient=ed on, Tests=0, Engine=EasyOCR
# Processing lab report 105/426: FBD-0425-PA-0031221_Vikash Kumar PreAuth Vidal TPA_compressed (1)_27-04-2025_0950-50_AM@G.pdf_page_12.png
# ✅ SUCCESS: Patient=Landmark
# Patieni, Tests=5, Engine=EasyOCR
# Processing lab report 106/426: DEL-0425-PA-0052238_F-THIRUSHANTHINIPREAUTHREQUEST_250427_1458@G.pdf_page_12.png
# ✅ SUCCESS: Patient=ICAL
# ABSOLUTE NEUTROPHIL, Tests=1, Engine=EasyOCR
# Processing lab report 107/426: DEL-0425-PA-0051395_FINAL BILL OF Mrs. GANIPISETTY RAJYALAKSHMI_27-04-2025_0328-59_PM@E.pdf_page_26.png
# ✅ SUCCESS: Patient=GANIPISETTY RAJYALAKSHMI
# IP, Tests=16, Engine=EasyOCR
# Processing lab report 108/426: DEL-0425-PA-0052162_FINAL BILL OF PT. MR. VIKAS TYAGI_compressed_27-04-2025_1215-38_PM@G.pdf_page_10.png
# ✅ SUCCESS: Patient=Holog
# NABL ACCREDITED, Tests=10, Engine=EasyOCR
# Processing lab report 109/426: GUR-0325-PA-0037914_Q-BABYSEEMAREPORTS29211_250428_1130@F.pdf_page_8.png
# ✅ SUCCESS: Patient=BHAGWAN DAS
# Department, Tests=10, Engine=EasyOCR
# Processing lab report 110/426: DEL-0425-PA-0052259_qqrr_27-04-2025_0524-02_PM@G.pdf_page_26.png
# ✅ SUCCESS: Patient=SERUM
# Final
# Referred, Tests=0, Engine=EasyOCR
# Processing lab report 111/426: DEL-0425-PA-0050734_ALL INVESTIGATION REPORTS_27-04-2025_0320-14_PM@G.pdf_page_17.png
# ✅ SUCCESS: Patient=BANTHALAPATIS LAVAKUMAR RAJu
# IPNO
# Mc, Tests=1, Engine=EasyOCR
# Processing lab report 112/426: DEL-0425-PA-0052212_F-LabReportMultiple_250427_1201@G.pdf_page_3.png
# ✅ SUCCESS: Patient=Received on, Tests=0, Engine=EasyOCR
# Processing lab report 113/426: FBD-0425-PA-0031292_F-KYC_PC_MR._PRADEEP_KUMAR_PARVAT_1_250427_1718@G.pdf_page_21.png
# ✅ SUCCESS: Patient=ed on, Tests=0, Engine=EasyOCR
# Processing lab report 114/426: DEL-0425-PA-0052208_F-1745734467763VENKATNARAYANAPREAUTH0001_250427_1150@G.pdf_page_18.png
# ✅ SUCCESS: Patient=SRIKARA
# SRIKARA, Tests=4, Engine=EasyOCR
# Processing lab report 115/426: DEL-0425-PA-0052208_F-1745734467763VENKATNARAYANAPREAUTH0001_250427_1150@G.pdf_page_17.png
# ✅ SUCCESS: Patient=ic shock
# LFT, Tests=13, Engine=EasyOCR
# Processing lab report 116/426: DEL-0425-PA-0052264_F-dilllrammm19021_250427_1906@G.pdf_page_12.png
# ✅ SUCCESS: Patient=Male
# ILa Mo, Tests=0, Engine=EasyOCR
# Processing lab report 117/426: DEL-0425-PA-0050734_ALL INVESTIGATION REPORTS_27-04-2025_0320-14_PM@G.pdf_page_4.png
# ✅ SUCCESS: Patient=HAEMOIQLOGX REPORL
# NORMALRANGE, Tests=0, Engine=EasyOCR
# Processing lab report 118/426: DEL-0425-PA-0052315_F-labreport_250428_1029@G.pdf_page_6.png
# ✅ SUCCESS: Patient=Mr MOHIDEEN, Tests=0, Engine=EasyOCR
# Processing lab report 119/426: GUR-0325-PA-0038152_Q-RAJESH_250427_1356@F.pdf_page_23.png
# ✅ SUCCESS: Patient=Samplel
# Time, Tests=3, Engine=EasyOCR
# Processing lab report 120/426: DEL-0425-PA-0049315_H_34982_9279936111_13_53_PREAUTHOFPOLAVARAPUSRIDEVI_22-04-2025_1200-25_PM@G.pdf_page_16.png
# ✅ SUCCESS: Patient=TIDISID
# DR, Tests=0, Engine=EasyOCR
# Processing lab report 121/426: DEL-0425-PA-0052368_F-1745820554223RANPALSINGHKUNTALPREUATH_250428_1146@G.pdf_page_23.png
# ✅ SUCCESS: Patient=Random Plasma Glucose value is, Tests=1, Engine=EasyOCR
# Processing lab report 122/426: DEL-0425-PA-0050734_ALL INVESTIGATION REPORTS_27-04-2025_0320-14_PM@G.pdf_page_16.png
# ✅ SUCCESS: Patient=CHETHANA
# Never Endlng, Tests=1, Engine=EasyOCR
# Processing lab report 123/426: DEL-0425-PA-0051555_E-MINAXIBENVYASFINAL_250427_0638@E.pdf_page_31.png
# ✅ SUCCESS: Patient=SANIIVAN
# Uday Park, Tests=0, Engine=EasyOCR
# Processing lab report 124/426: DEL-0425-PA-0052248_DEL-0425-PA-0052238 pa_27-04-2025_0405-42_PM@G.pdf_page_11.png
# ✅ SUCCESS: Patient=ER CARE GROUP, Tests=2, Engine=EasyOCR
# Processing lab report 125/426: FBD-0425-PA-0031292_F-KYC_PC_MR._PRADEEP_KUMAR_PARVAT_1_250427_1718@G.pdf_page_28.png
# ✅ SUCCESS: Patient=ed on, Tests=2, Engine=EasyOCR
# Processing lab report 126/426: GUR-0325-PA-0036985_Q-RAMFAL_250427_1347@F.pdf_page_27.png
# ✅ SUCCESS: Patient=can not be confirmed, Tests=3, Engine=EasyOCR
# Processing lab report 127/426: GUR-0425-CL-0177710_EMP_SRT_25042025131749INVR_Pallavi Reports.pdf_page_13.png
# ✅ SUCCESS: Patient=oms such as weight gain, Tests=3, Engine=EasyOCR
# Processing lab report 128/426: GUR-0425-CL-0196324_INW_GUR-0425-CL-0196324_27042025165908.pdf_page_16.png
# ✅ SUCCESS: Patient=Housing Society Limited, Tests=0, Engine=EasyOCR
# Processing lab report 129/426: GUR-0425-CL-0195381_EMP_INW_19042025183215INVR_LabReport.pdf_page_12.png
# ✅ SUCCESS: Patient=Information
# Client, Tests=0, Engine=EasyOCR
# Processing lab report 130/426: GUR-0425-CL-0194518_INW_ilovepdf_merged_28042025114132.pdf_page_16.png
# ✅ SUCCESS: Patient=omatic patient Non alcoholic fatty
# manifestation of metabolic syndrome In most
# In an
# increased AST, Tests=8, Engine=EasyOCR
# Processing lab report 131/426: GUR-0425-CL-0177710_EMP_SRT_25042025131749INVR_Pallavi Reports.pdf_page_6.png
# ✅ SUCCESS: Patient=also is iron deficient, Tests=2, Engine=EasyOCR
# Processing lab report 132/426: GUR-0325-PA-0043338_Q-DINESHIPDFILE11zon1_250422_1309@F.pdf_page_33.png
# ✅ SUCCESS: Patient=Observed Values
# Biological Ref, Tests=4, Engine=EasyOCR
# Processing lab report 133/426: GUR-0425-CL-0194864_EMP_INW_25042025101859INVR_Preeti Yellan Pathology Reports Shreeyas Hospital.pdf_page_1.png
# ✅ SUCCESS: Patient=HELPING YOUTO GET, Tests=3, Engine=EasyOCR
# Processing lab report 134/426: GUR-0325-PA-0038152_Q-RAJESH_250427_1356@F.pdf_page_27.png
# ✅ SUCCESS: Patient=can not be confirmed, Tests=5, Engine=EasyOCR
# Processing lab report 135/426: GUR-0425-PA-0044765_Q-PURAVALLINVESTIGATIONREPORTANDXRAYREPORTANDVITALCHART_250428_1134@F.pdf_page_3.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 136/426: GUR-0425-PA-0047249_CH ACHIYYA CHOWDARY 0047249_28-04-2025_1118-26_AM@E.pdf_page_25.png
# ✅ SUCCESS: Patient=IP
# Episode
# Mobile, Tests=5, Engine=EasyOCR
# Processing lab report 137/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_89.png
# ✅ SUCCESS: Patient=Sampk Received, Tests=0, Engine=EasyOCR
# Processing lab report 138/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_79.png
# ✅ SUCCESS: Patient=Ishwrar Hospltal Cashless, Tests=1, Engine=EasyOCR
# Processing lab report 139/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_86.png
# ✅ SUCCESS: Patient=Value
# Unit
# Blo Ref Interval, Tests=1, Engine=EasyOCR
# Processing lab report 140/426: GUR-0425-PA-0044765_Q-PURAVALLINVESTIGATIONREPORTANDXRAYREPORTANDVITALCHART_250428_1134@F.pdf_page_8.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=1, Engine=EasyOCR
# Processing lab report 141/426: GUR-0425-PA-0047910_Q-MANISHA13.04.20250001compressed_250427_1054@F.pdf_page_41.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=3, Engine=EasyOCR
# Processing lab report 142/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_87.png
# ✅ SUCCESS: Patient=HHISHWAR
# MULTI SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 143/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_126.png
# ✅ SUCCESS: Patient=BLCOO SUGAR, Tests=1, Engine=EasyOCR
# Processing lab report 144/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_125.png
# ✅ SUCCESS: Patient=CRP QUANTITATIVE, Tests=4, Engine=EasyOCR
# Processing lab report 145/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_101.png
# ✅ SUCCESS: Patient=HHISHWAR
# MULTI SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 146/426: GUR-0425-PA-0045348_Q-FINALBILLWITHDISCHARGEDOCUMENTS_250411_1130@F.pdf_page_85.png
# ✅ SUCCESS: Patient=HISHWAR
# MULTI SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 147/426: GUR-0425-PA-0049535_Q-11zonmergedFiles20250424T142233.73111zon_250424_1441@F.pdf_page_61.png
# ✅ SUCCESS: Patient=lOSCAR SUPER SPECIALITY, Tests=1, Engine=EasyOCR
# Processing lab report 148/426: GUR-0425-PA-0049535_Q-11zonmergedFiles20250427T123253.76311zon_250427_1234@F.pdf_page_37.png
# ✅ SUCCESS: Patient=Name
# Dale, Tests=1, Engine=EasyOCR
# Processing lab report 149/426: GUR-0425-PA-0049535_Q-11zonmergedFiles20250424T142233.73111zon_250424_1441@F.pdf_page_67.png
# ✅ SUCCESS: Patient=MEENAKSHI
# Patient Name, Tests=2, Engine=EasyOCR
# Processing lab report 150/426: GUR-0425-PA-0048851_Q-FINAL0001_250422_1251@F.pdf_page_47.png
# ✅ SUCCESS: Patient=INAL VERMA
# No, Tests=1, Engine=EasyOCR
# Processing lab report 151/426: GUR-0425-PA-0048512_Q-POOJA4759000111zon_250424_1524@F.pdf_page_48.png
# ✅ SUCCESS: Patient=DSCAR SUPER SPECIALITY, Tests=2, Engine=EasyOCR
# Processing lab report 152/426: GUR-0425-PA-0047954_Q-FINAL0001_250422_1558@F.pdf_page_36.png
# ✅ SUCCESS: Patient=Id
# Dr, Tests=0, Engine=EasyOCR
# Processing lab report 153/426: GUR-0425-PA-0049533_Q-VIKRAM_250427_1414@F.pdf_page_31.png
# ✅ SUCCESS: Patient=Mobile
# MR, Tests=1, Engine=EasyOCR
# Processing lab report 154/426: GUR-0425-PA-0048512_Q-POOJA4759000111zon_250424_1524@F.pdf_page_43.png
# ✅ SUCCESS: Patient=With Methodology
# Biological Ref Interval
# Result
# Unlt
# Culture, Tests=0, Engine=EasyOCR
# Processing lab report 155/426: GUR-0425-PA-0049511_Q-QueryReply_250423_1100@F.pdf_page_67.png
# ✅ SUCCESS: Patient=Pathologist
# DrRK BAJAJ, Tests=0, Engine=EasyOCR
# Processing lab report 156/426: GUR-0425-PA-0048851_Q-FINAL0001_250422_1251@F.pdf_page_50.png
# ✅ SUCCESS: Patient=INAL VERMA
# No, Tests=0, Engine=EasyOCR
# Processing lab report 157/426: GUR-0425-PA-0048512_Q-POOJA4759000111zon_250424_1524@F.pdf_page_35.png
# ✅ SUCCESS: Patient=ANTI HCV
# COMPONENT
# UnItS
# ANI HCV
# RESULTS
# REFF RANGE
# NEGATIVE
# PathologtstTechnologist
# Dr, Tests=0, Engine=EasyOCR
# Processing lab report 158/426: GUR-0425-PA-0051495_Q-FINAL0001_250427_1709@F.pdf_page_53.png
# ✅ SUCCESS: Patient=INAL VERMA
# NNo, Tests=3, Engine=EasyOCR
# Processing lab report 159/426: GUR-0425-PA-0051111_Q-FINAL0001_250427_1153@F.pdf_page_41.png
# ✅ SUCCESS: Patient=Srl No, Tests=1, Engine=EasyOCR
# Processing lab report 160/426: GUR-0425-PA-0049547_Q-BECHUIPD1104_250424_1548@F.pdf_page_57.png
# ✅ SUCCESS: Patient=DR LAKIMCHAND AMBAPKAR, Tests=2, Engine=EasyOCR
# Processing lab report 161/426: GUR-0425-PA-0049547_Q-BECHUIPD1104_250424_1548@F.pdf_page_32.png
# ✅ SUCCESS: Patient=AMBAPKAR
# NORMAL RANCE, Tests=0, Engine=EasyOCR
# Processing lab report 162/426: GUR-0425-PA-0051111_Q-FINAL0001_250427_1153@F.pdf_page_60.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 163/426: GUR-0425-PA-0049547_Q-BECHUIPD1104_250424_1548@F.pdf_page_36.png
# ✅ SUCCESS: Patient=Lun
# KHERA
# CONSULTAINT, Tests=0, Engine=EasyOCR
# Processing lab report 164/426: GUR-0425-PA-0050464_Q-RAJBALA201030001compressed_250423_1248@F.pdf_page_75.png
# ✅ SUCCESS: Patient=Ujala
# Cygnus SuperSpeciality, Tests=1, Engine=EasyOCR
# Processing lab report 165/426: GUR-0425-PA-0050321_GUR0425PA0050321_E_27-04-2025_0740-55_PM@F.pdf_page_21.png
# ✅ SUCCESS: Patient=Fatiert
# Cllnical Biochemislry, Tests=0, Engine=EasyOCR
# Processing lab report 166/426: GUR-0425-PA-0050321_GUR0425PA0050321_E_27-04-2025_0740-55_PM@F.pdf_page_18.png
# ✅ SUCCESS: Patient=Palier
# Hemadlogy
# CBC, Tests=1, Engine=EasyOCR
# Processing lab report 167/426: GUR-0425-PA-0049999_Q-KRISHNAKUMAR10413compressed_250427_1526@F.pdf_page_54.png
# ✅ SUCCESS: Patient=Mrs Krishnakumari
# Age, Tests=3, Engine=EasyOCR
# Processing lab report 168/426: GUR-0425-PA-0051584_Q-11zonmergedFiles2911zon_250427_1452@F.pdf_page_56.png
# ✅ SUCCESS: Patient=OSCAR SUPER SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 169/426: GUR-0425-PA-0051634_Q-KANTADEVI20.04.20250001compressed_250427_1050@F.pdf_page_31.png
# ✅ SUCCESS: Patient=Patient Id, Tests=1, Engine=EasyOCR
# Processing lab report 170/426: GUR-0425-PA-0051612_Q-DEEPAKKUMAR4814000111zon_250427_1341@F.pdf_page_42.png
# ✅ SUCCESS: Patient=OECAR SUPER SPECIALITY, Tests=1, Engine=EasyOCR
# Processing lab report 171/426: GUR-0425-PA-0051634_Q-KANTADEVI20.04.20250001compressed_250427_1050@F.pdf_page_44.png
# ✅ SUCCESS: Patient=Id
# No, Tests=2, Engine=EasyOCR
# Processing lab report 172/426: GUR-0425-PA-0051559_Q-11zonmergedFiles2711zon_250427_1425@F.pdf_page_51.png
# ✅ SUCCESS: Patient=OSCAR SUPER SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 173/426: GUR-0425-PA-0051634_Q-KANTADEVI20.04.20250001compressed_250427_1050@F.pdf_page_33.png
# ✅ SUCCESS: Patient=of the parasite, Tests=0, Engine=EasyOCR
# Processing lab report 174/426: GUR-0425-PA-0051604_Q-ASHISHKUMAR4813000111zon_250427_1255@F.pdf_page_31.png
# ✅ SUCCESS: Patient=COMPONEN
# HIV, Tests=0, Engine=EasyOCR
# Processing lab report 175/426: GUR-0425-PA-0051619_Q-RADHA20.04.20250001compressed_250427_1038@F.pdf_page_32.png
# ✅ SUCCESS: Patient=SWASTIK HOSPITA
# Jhajjar, Tests=12, Engine=EasyOCR
# Processing lab report 176/426: GUR-0425-PA-0051642_Q-DARSHANA20.04.20250001compressed3_250427_1609@F.pdf_page_34.png
# ✅ SUCCESS: Patient=infection
# in order, Tests=0, Engine=EasyOCR
# Processing lab report 177/426: GUR-0425-PA-0051584_Q-11zonmergedFiles2911zon_250427_1452@F.pdf_page_51.png
# ✅ SUCCESS: Patient=OSCAR SUPER SPECIALITY, Tests=1, Engine=EasyOCR
# Processing lab report 178/426: GUR-0425-PA-0051559_Q-11zonmergedFiles2711zon_250427_1425@F.pdf_page_34.png
# ✅ SUCCESS: Patient=RAKHI
# Patient Nan
# pale
# Mobile No, Tests=1, Engine=EasyOCR
# Processing lab report 179/426: GUR-0425-PA-0051559_Q-11zonmergedFiles2711zon_250427_1425@F.pdf_page_73.png
# ✅ SUCCESS: Patient=REEE RANGE
# RESULTS
# COMPONENT, Tests=0, Engine=EasyOCR
# Processing lab report 180/426: GUR-0425-PA-0051559_Q-11zonmergedFiles2711zon_250427_1425@F.pdf_page_63.png
# ✅ SUCCESS: Patient=OICAR SUPER SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 181/426: GUR-0425-PA-0051619_Q-RADHA20.04.20250001compressed_250427_1038@F.pdf_page_30.png
# ✅ SUCCESS: Patient=YOGESH CHAHAR
# CULTURE, Tests=0, Engine=EasyOCR
# Processing lab report 182/426: GUR-0425-PA-0051651_Q-ARCHANA20.04.20250001compressed_250427_1427@F.pdf_page_32.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 183/426: GUR-0425-PA-0051769_Q-DEVSINGH19.04.20250001compressed1_250427_1433@F.pdf_page_30.png
# ✅ SUCCESS: Patient=AMPICILLIN
# AMOXYCILLIN, Tests=0, Engine=EasyOCR
# Processing lab report 184/426: GUR-0425-PA-0051757_Q-HEMANTDHALWAL19.04.20250001compressed_250427_1031@F.pdf_page_53.png
# ✅ SUCCESS: Patient=Id
# HAEMATOLOGY, Tests=1, Engine=EasyOCR
# Processing lab report 185/426: GUR-0425-PA-0051761_Q-NEHA19.04.20250001compressed_250427_1034@F.pdf_page_30.png
# ✅ SUCCESS: Patient=Patient Id
# SWASTIK, Tests=11, Engine=EasyOCR
# Processing lab report 186/426: GUR-0425-PA-0051651_Q-ARCHANA20.04.20250001compressed_250427_1427@F.pdf_page_39.png
# ✅ SUCCESS: Patient=Patient Id, Tests=6, Engine=EasyOCR
# Processing lab report 187/426: GUR-0425-PA-0052092_Q-11zonmergedFiles20250424T145803.40111zon_250424_1459@F.pdf_page_73.png
# ✅ SUCCESS: Patient=DSCAR SUPER SPECIALITY, Tests=1, Engine=EasyOCR
# Processing lab report 188/426: GUR-0425-PA-0051761_Q-NEHA19.04.20250001compressed_250427_1034@F.pdf_page_45.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=3, Engine=EasyOCR
# Processing lab report 189/426: GUR-0425-PA-0051725_Q-DEVKI19.04.20250001compressed_250427_1059@F.pdf_page_47.png
# ✅ SUCCESS: Patient=Id
# PHYSICAL EXAMINATION
# ml, Tests=3, Engine=EasyOCR
# Processing lab report 190/426: GUR-0425-PA-0051769_Q-DEVSINGH19.04.20250001compressed1_250427_1433@F.pdf_page_45.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=1, Engine=EasyOCR
# Processing lab report 191/426: GUR-0425-PA-0051667_Q-ANJALIGOSWAMI20.04.20250001compressed_250427_1632@F.pdf_page_41.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=3, Engine=EasyOCR
# Processing lab report 192/426: GUR-0425-PA-0051651_Q-ARCHANA20.04.20250001compressed_250427_1427@F.pdf_page_45.png
# ✅ SUCCESS: Patient=SWASTIK HOSPITN
# Jhajjar, Tests=1, Engine=EasyOCR
# Processing lab report 193/426: GUR-0425-PA-0051757_Q-HEMANTDHALWAL19.04.20250001compressed_250427_1031@F.pdf_page_62.png
# ✅ SUCCESS: Patient=Id
# SEROLOGY, Tests=1, Engine=EasyOCR
# Processing lab report 194/426: GUR-0425-PA-0052251_Q-KRANTIDEVI21.04.20250001compressed_250427_1106@F.pdf_page_29.png
# ✅ SUCCESS: Patient=YOGESH CHAHAR, Tests=0, Engine=EasyOCR
# Processing lab report 195/426: GUR-0425-PA-0052234_Q-REPORTS_250422_1655@F.pdf_page_19.png
# ✅ SUCCESS: Patient=DAS
# Department, Tests=8, Engine=EasyOCR
# Processing lab report 196/426: GUR-0425-PA-0052271_Q-RAMFEERPANDEY21.04.20250001compressed1_250427_1439@F.pdf_page_42.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=3, Engine=EasyOCR
# Processing lab report 197/426: GUR-0425-PA-0052276_Q-FINAL0001_250427_1711@F.pdf_page_32.png
# ✅ SUCCESS: Patient=INAL VERMA
# No, Tests=4, Engine=EasyOCR
# Processing lab report 198/426: GUR-0425-PA-0052255_Q-ANU21.04.20250001compressed1_250427_1025@F.pdf_page_40.png
# ✅ SUCCESS: Patient=Id
# Noalvauc
# HAEMATOLOGY
# COMPLETE BLOOD CQUNL, Tests=2, Engine=EasyOCR
# Processing lab report 199/426: GUR-0425-PA-0052255_Q-ANU21.04.20250001compressed1_250427_1025@F.pdf_page_37.png
# ✅ SUCCESS: Patient=EXPECTED VALUES, Tests=2, Engine=EasyOCR
# Processing lab report 200/426: GUR-0425-PA-0052255_Q-ANU21.04.20250001compressed1_250427_1025@F.pdf_page_30.png
# ✅ SUCCESS: Patient=SWASTIK HOSPIT
# Jhajjar, Tests=12, Engine=EasyOCR
# Processing lab report 201/426: GUR-0425-PA-0052259_Q-SOPENDAR10425_250427_1518@F.pdf_page_38.png
# ✅ SUCCESS: Patient=Property ID, Tests=5, Engine=EasyOCR
# Processing lab report 202/426: GUR-0425-PA-0052271_Q-RAMFEERPANDEY21.04.20250001compressed1_250427_1439@F.pdf_page_40.png
# ✅ SUCCESS: Patient=Patient Id, Tests=2, Engine=EasyOCR
# Processing lab report 203/426: GUR-0425-PA-0052234_Q-REPORTS_250422_1655@F.pdf_page_10.png
# ✅ SUCCESS: Patient=HAGWAN DAS
# Department, Tests=0, Engine=EasyOCR
# Processing lab report 204/426: GUR-0425-PA-0052242_Q-GITADEVI20.04.20250001compressed_250427_1036@F.pdf_page_33.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 205/426: GUR-0425-PA-0052251_Q-KRANTIDEVI21.04.20250001compressed_250427_1106@F.pdf_page_41.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=1, Engine=EasyOCR
# Processing lab report 206/426: GUR-0425-PA-0052925_Q-BIJENDERVATS21.04.20250001compressed_250427_1101@F.pdf_page_49.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 207/426: GUR-0425-PA-0052830_Q-NAVITA21.04.20250001compressed_250427_1047@F.pdf_page_29.png
# ✅ SUCCESS: Patient=AMOXYCLAVE
# CEFUROXIME, Tests=0, Engine=EasyOCR
# Processing lab report 208/426: GUR-0425-PA-0052331_Q-gomati201590001compressed_250422_1706@F.pdf_page_53.png
# ✅ SUCCESS: Patient=Cygnus
# Cygnus SuperSpeciality, Tests=1, Engine=EasyOCR
# Processing lab report 209/426: GUR-0425-PA-0052918_Q-SONU104890001merged2_250427_1622@F.pdf_page_37.png
# ✅ SUCCESS: Patient=OPD IPD, Tests=8, Engine=EasyOCR
# Processing lab report 210/426: GUR-0425-PA-0052974_claim love yadav_27-04-2025_0232-13_PM.pdf_page_38.png
# ✅ SUCCESS: Patient=Srs
# SiNGH Ho, Tests=3, Engine=EasyOCR
# Processing lab report 211/426: GUR-0425-PA-0052940_Q-DULARI104920001mergedcompressed_250427_1625@F.pdf_page_33.png
# ✅ SUCCESS: Patient=Urine Routine Examination, Tests=1, Engine=EasyOCR
# Processing lab report 212/426: GUR-0425-PA-0052331_Q-gomati201590001compressed_250422_1706@F.pdf_page_61.png
# ✅ SUCCESS: Patient=Bed No
# Loc, Tests=2, Engine=EasyOCR
# Processing lab report 213/426: GUR-0425-PA-0052925_Q-BIJENDERVATS21.04.20250001compressed_250427_1101@F.pdf_page_40.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=4, Engine=EasyOCR
# Processing lab report 214/426: GUR-0425-PA-0052974_claim love yadav_27-04-2025_0232-13_PM.pdf_page_28.png
# ✅ SUCCESS: Patient=Rislykkesh Kumar
# Dr, Tests=7, Engine=EasyOCR
# Processing lab report 215/426: GUR-0425-PA-0053227_Q-BABYOFANJLI14042025compressed_250428_1153@F.pdf_page_45.png
# ✅ SUCCESS: Patient=MAHARISHI MARKANDESHWAR COLLEGE, Tests=2, Engine=EasyOCR
# Processing lab report 216/426: GUR-0425-PA-0052925_Q-BIJENDERVATS21.04.20250001compressed_250427_1101@F.pdf_page_41.png
# ✅ SUCCESS: Patient=Patient Id, Tests=3, Engine=EasyOCR
# Processing lab report 217/426: GUR-0425-PA-0052831_Q-FINAL0001_250427_1155@F.pdf_page_46.png
# ✅ SUCCESS: Patient=QUALIIK
# ADVANTA
# SAFELY, Tests=0, Engine=EasyOCR
# Processing lab report 218/426: GUR-0425-PA-0053395_Q-VIMLA21.04.20250001compressed_250427_1103@F.pdf_page_48.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=1, Engine=EasyOCR
# Processing lab report 219/426: GUR-0425-PA-0053274_Q-sonamatidevi10227compressed_250427_1530@F.pdf_page_40.png
# ✅ SUCCESS: Patient=Property ID, Tests=2, Engine=EasyOCR
# Processing lab report 220/426: GUR-0425-PA-0053405_Q-RANJANADEVI21.04.20250001compressed_250427_1041@F.pdf_page_42.png
# ✅ SUCCESS: Patient=ed at
# Ref, Tests=0, Engine=EasyOCR
# Processing lab report 221/426: GUR-0425-PA-0053405_Q-RANJANADEVI21.04.20250001compressed_250427_1041@F.pdf_page_40.png
# ✅ SUCCESS: Patient=are usually detected
# by Typhidot at the onset of fever, Tests=0, Engine=EasyOCR
# Processing lab report 222/426: GUR-0425-PA-0053274_Q-sonamatidevi10227compressed_250427_1530@F.pdf_page_30.png
# ✅ SUCCESS: Patient=Property ID, Tests=0, Engine=EasyOCR
# Processing lab report 223/426: GUR-0425-PA-0053395_Q-VIMLA21.04.20250001compressed_250427_1103@F.pdf_page_46.png
# ✅ SUCCESS: Patient=IMMUNOLOGY
# ANTICYCLIC CITRULLINATED, Tests=0, Engine=EasyOCR
# Processing lab report 224/426: GUR-0425-PA-0053395_Q-VIMLA21.04.20250001compressed_250427_1103@F.pdf_page_33.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 225/426: GUR-0425-PA-0053260_Q-SARVANKUMAR10451_250427_1617@F.pdf_page_28.png
# ✅ SUCCESS: Patient=Property ID, Tests=0, Engine=EasyOCR
# Processing lab report 226/426: GUR-0425-PA-0053405_Q-RANJANADEVI21.04.20250001compressed_250427_1041@F.pdf_page_38.png
# ✅ SUCCESS: Patient=Jhajjar Road Bahadurgarh, Tests=2, Engine=EasyOCR
# Processing lab report 227/426: GUR-0425-PA-0053260_Q-SARVANKUMAR10451_250427_1617@F.pdf_page_35.png
# ✅ SUCCESS: Patient=ic shock, Tests=0, Engine=EasyOCR
# Processing lab report 228/426: GUR-0425-PA-0053454_Q-11zonmergedFiles2411zon_250427_1324@F.pdf_page_27.png
# ✅ SUCCESS: Patient=IRREOH
# KELERANGE
# ISERUM, Tests=1, Engine=EasyOCR
# Processing lab report 229/426: GUR-0425-PA-0053408_Q-SATISHKUMAR19.04.20250001compressed_250427_1052@F.pdf_page_37.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 230/426: GUR-0425-PA-0053454_Q-11zonmergedFiles2411zon_250427_1324@F.pdf_page_30.png
# ✅ SUCCESS: Patient=REFE RANGE
# COMPONEN
# RESULIS
# UNITS
# CRP, Tests=1, Engine=EasyOCR
# Processing lab report 231/426: GUR-0425-PA-0053481_Q-CHHAYADEVI21.04.20250001compressed_250427_1617@F.pdf_page_38.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 232/426: GUR-0425-PA-0053434_Q-PREETI4837000111zon_250427_1314@F.pdf_page_42.png
# ✅ SUCCESS: Patient=PREE
# Patient Name, Tests=1, Engine=EasyOCR
# Processing lab report 233/426: GUR-0425-PA-0053434_Q-PREETI4837000111zon_250427_1314@F.pdf_page_35.png
# ✅ SUCCESS: Patient=Doctor Nime
# KUMARI, Tests=0, Engine=EasyOCR
# Processing lab report 234/426: GUR-0425-PA-0053405_Q-RANJANADEVI21.04.20250001compressed_250427_1041@F.pdf_page_46.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 235/426: GUR-0425-PA-0053454_Q-11zonmergedFiles2411zon_250427_1324@F.pdf_page_36.png
# ✅ SUCCESS: Patient=OSCAR SUPER SPECIALITY, Tests=0, Engine=EasyOCR
# Processing lab report 236/426: GUR-0425-PA-0053411_Q-PREETIKA19.04.20250001compressed_250427_1027@F.pdf_page_41.png
# ✅ SUCCESS: Patient=ed at
# Ref, Tests=0, Engine=EasyOCR
# Processing lab report 237/426: GUR-0425-PA-0053434_Q-PREETI4837000111zon_250427_1314@F.pdf_page_38.png
# ✅ SUCCESS: Patient=Patient Nime, Tests=0, Engine=EasyOCR
# Processing lab report 238/426: GUR-0425-PA-0053481_Q-CHHAYADEVI21.04.20250001compressed_250427_1617@F.pdf_page_34.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=0, Engine=EasyOCR
# Processing lab report 239/426: GUR-0425-PA-0053408_Q-SATISHKUMAR19.04.20250001compressed_250427_1052@F.pdf_page_30.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=2, Engine=EasyOCR
# Processing lab report 240/426: GUR-0425-PA-0053605_RAJ RANI CLAIM FILE 23.04.25_27-04-2025_0257-11_PM@E.pdf_page_27.png
# ✅ SUCCESS: Patient=sarvodaya
# KALYANI
# DIAGNOSTICS, Tests=0, Engine=EasyOCR
# Processing lab report 241/426: GUR-0425-PA-0053481_Q-CHHAYADEVI21.04.20250001compressed_250427_1617@F.pdf_page_42.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=3, Engine=EasyOCR
# Processing lab report 242/426: GUR-0425-PA-0053605_RAJ RANIREPORTS_0001 (1)_23-04-2025_0442-32_PM@F.pdf_page_9.png
# ✅ SUCCESS: Patient=DAULATI
# MBBSMD CONSULTANT
# Microbiolgy
# PATHOLOGIST
# Radha Swami Satsang Bhawan, Tests=0, Engine=EasyOCR
# Processing lab report 243/426: GUR-0425-PA-0053566_Q-SHYAMA000111zon_250427_1643@F.pdf_page_34.png
# ✅ SUCCESS: Patient=Timing
# COMPLETE RANGE, Tests=0, Engine=EasyOCR
# Processing lab report 244/426: GUR-0425-PA-0053884_Q-112674POOJADEVI_250427_1547@F.pdf_page_32.png
# ✅ SUCCESS: Patient=ultant Physician
# KESHARWANP, Tests=0, Engine=EasyOCR
# Processing lab report 245/426: GUR-0425-PA-0053590_E-FinalBillAndDischargeSummary_250427_1355@E.pdf_page_100.png
# ✅ SUCCESS: Patient=Flnal
# Alc Status, Tests=3, Engine=EasyOCR
# Processing lab report 246/426: GUR-0425-PA-0053930_Q-REKHA10500_250427_1509@F.pdf_page_27.png
# ✅ SUCCESS: Patient=Rekha Devi
# Ref By
# Dr, Tests=3, Engine=EasyOCR
# Processing lab report 247/426: GUR-0425-PA-0053567_Q-PT.ROSHNIESIBUNCH11zon_250427_1622@F.pdf_page_63.png
# ✅ SUCCESS: Patient=Dharambir
# Deshwal, Tests=2, Engine=EasyOCR
# Processing lab report 248/426: GUR-0425-PA-0053481_Q-CHHAYADEVI21.04.20250001compressed_250427_1617@F.pdf_page_39.png
# ✅ SUCCESS: Patient=Id
# Srl No, Tests=3, Engine=EasyOCR
# Processing lab report 249/426: GUR-0425-PA-0053930_Q-REKHA10500_250427_1509@F.pdf_page_28.png
# ✅ SUCCESS: Patient=Rekha Devi
# Ref By
# Dr, Tests=0, Engine=EasyOCR
# Processing lab report 250/426: GUR-0425-PA-0053567_Q-PT.ROSHNIESIBUNCH11zon_250427_1622@F.pdf_page_41.png
# ✅ SUCCESS: Patient=Dharambir Doshwal, Tests=4, Engine=EasyOCR
# Processing lab report 251/426: GUR-0425-PA-0053567_Q-PT.ROSHNIESIBUNCH11zon_250427_1622@F.pdf_page_70.png
# ✅ SUCCESS: Patient=Dharambir Deshwal
# Dr, Tests=13, Engine=EasyOCR
# Processing lab report 252/426: GUR-0425-PA-0053566_Q-SHYAMA000111zon_250427_1643@F.pdf_page_29.png
# ✅ SUCCESS: Patient=AMABH Accrediled Mullispecialllly, Tests=0, Engine=EasyOCR
# Processing lab report 253/426: GUR-0425-PA-0054524_E-FinalbillanddischargeSangitadevi_250427_1834@E.pdf_page_11.png
# ✅ SUCCESS: Patient=NAME
# MRS SANGITA DEVI, Tests=1, Engine=EasyOCR
# Processing lab report 254/426: GUR-0425-PA-0054021_Q-manhorfinalbill_250427_1343@F.pdf_page_29.png
# ✅ SUCCESS: Patient=Dr Vshal Yadav, Tests=6, Engine=EasyOCR
# Processing lab report 255/426: GUR-0425-PA-0053972_E-SANDEEPKUMARMID_250427_1418@E.pdf_page_12.png
# ✅ SUCCESS: Patient=IP
# Episode
# Aakash, Tests=4, Engine=EasyOCR
# Processing lab report 256/426: GUR-0425-PA-0054043_Q-VIRENDER000111zon_250423_1719@F.pdf_page_22.png
# ✅ SUCCESS: Patient=Computerised
# Timing
# COHPLETE, Tests=2, Engine=EasyOCR
# Processing lab report 257/426: GUR-0425-PA-0054021_Q-manhorfinalbill_250427_1343@F.pdf_page_40.png
# ✅ SUCCESS: Patient=Dra Vshal Yadav, Tests=4, Engine=EasyOCR
# Processing lab report 258/426: GUR-0425-PA-0054745_Q-REPORTS_250427_1041@F.pdf_page_7.png
# ✅ SUCCESS: Patient=Type
# BIOCHEMISTRY
# LFT, Tests=8, Engine=EasyOCR
# Processing lab report 259/426: GUR-0425-PA-0053972_E-SANDEEPKUMARMID_250427_1418@E.pdf_page_8.png
# ✅ SUCCESS: Patient=SANDEEP   KUMAR
# Patient Name, Tests=0, Engine=EasyOCR
# Processing lab report 260/426: GUR-0425-PA-0054811_Q-GUDDUKUMAR10534_250427_1457@F.pdf_page_31.png
# ✅ SUCCESS: Patient=Guddu Kumar, Tests=0, Engine=EasyOCR
# Processing lab report 261/426: GUR-0425-PA-0054524_E-FinalbillanddischargeSangitadevi_250427_1834@E.pdf_page_14.png
# ✅ SUCCESS: Patient=SANGITA DEVI
# TINE, Tests=1, Engine=EasyOCR
# Processing lab report 262/426: GUR-0425-PA-0054044_Q-FINAL0001_250427_1157@F.pdf_page_36.png
# ✅ SUCCESS: Patient=Id
# Dr, Tests=1, Engine=EasyOCR
# Processing lab report 263/426: GUR-0425-PA-0054840_Q-pawankumarfinal_250427_1337@F.pdf_page_40.png
# ✅ SUCCESS: Patient=ed as proof of absence of
# hypersensitivity only
# after normal reactivity to non, Tests=0, Engine=EasyOCR
# Processing lab report 264/426: GUR-0425-PA-0055398_SUNILA ARORA INVESTIGATION  FOR ENHANCMENT _27-04-2025_1111-09_AM.pdf_page_6.png
# ✅ SUCCESS: Patient=SUNILA ARORA, Tests=1, Engine=EasyOCR
# Processing lab report 265/426: GUR-0425-PA-0055117_E-SANTKUMARREPORTS27042025_250427_1719@E.pdf_page_9.png
# ✅ SUCCESS: Patient=ion
# Result
# Biological Ref Range
# BIOCHEMISTRY
# CREATININE
# Method, Tests=1, Engine=EasyOCR
# Processing lab report 266/426: GUR-0425-PA-0055398_SUNILA ARORA INVESTIGATION  FOR ENHANCMENT _26-04-2025_0642-20_PM@G.pdf_page_19.png
# ✅ SUCCESS: Patient=SUNILA ARORA, Tests=1, Engine=EasyOCR
# Processing lab report 267/426: GUR-0425-PA-0055258_Q-BIMLA000411zon_250423_1700@F.pdf_page_23.png
# ✅ SUCCESS: Patient=ANABH Accredited Multispecialilty, Tests=3, Engine=EasyOCR
# Processing lab report 268/426: GUR-0425-PA-0054989_Q-112752REETADEVI_250427_1429@F.pdf_page_37.png
# ✅ SUCCESS: Patient=Type
# IP, Tests=0, Engine=EasyOCR
# Processing lab report 269/426: GUR-0425-PA-0054840_Q-pawankumarfinal_250427_1337@F.pdf_page_36.png
# ✅ SUCCESS: Patient=Consultant Pathologist
# Near, Tests=3, Engine=EasyOCR
# Processing lab report 270/426: GUR-0425-PA-0054886_Q-112714RASMITA_250427_1433@F.pdf_page_32.png
# ✅ SUCCESS: Patient=JJ INSTITUTE
# OF, Tests=0, Engine=EasyOCR
# Processing lab report 271/426: GUR-0425-PA-0055247_Q-Muraliquery_250427_1736@F.pdf_page_5.png
# ✅ SUCCESS: Patient=MURALLG
# Name
# HAEMATOLOGY, Tests=17, Engine=EasyOCR
# Processing lab report 272/426: GUR-0425-PA-0055258_Q-BIMLA000411zon_250423_1700@F.pdf_page_13.png
# ✅ SUCCESS: Patient=COMPLETE RANGE QF, Tests=8, Engine=EasyOCR
# Processing lab report 273/426: GUR-0425-PA-0055053_Q-1745410679910ArtiKumariinv0001_250423_1751@F.pdf_page_8.png
# ✅ SUCCESS: Patient=ID
# FH, Tests=4, Engine=EasyOCR
# Processing lab report 274/426: GUR-0425-PA-0054989_Q-112752REETADEVI_250427_1429@F.pdf_page_31.png
# ✅ SUCCESS: Patient=Type
# IP
# Consultant Doctor
# IP No, Tests=1, Engine=EasyOCR
# Processing lab report 275/426: GUR-0425-PA-0055398_SUNILA ARORA INVESTIGATION  FOR ENHANCMENT _27-04-2025_1111-09_AM.pdf_page_16.png
# ✅ SUCCESS: Patient=SUNILA ARORA
# Accepted on, Tests=7, Engine=EasyOCR
# ...
# ✅ SUCCESS: Patient=Patient ID
# Patients, Tests=3, Engine=EasyOCR
# Processing lab report 419/426: MUM-0125-PA-0001141_W2500438UNADKAT ASHWIN_27-04-2025_1002-19_AM.pdf_page_91.png
# ✅ SUCCESS: Patient=ICALIIMPEDENCE
# Monocytes, Tests=2, Engine=EasyOCR
# Processing lab report 420/426: MUM-0125-PA-0001141_W2500438UNADKAT ASHWIN_27-04-2025_1001-12_AM.pdf_page_74.png
# ✅ SUCCESS: Patient=and
# PrInted On
# Printed By, Tests=3, Engine=EasyOCR
# Processing lab report 421/426: MUM-0425-PA-0004300_REPORTS_27-04-2025_0134-06_PM@G.pdf_page_13.png
# ✅ SUCCESS: Patient=Result Value, Tests=10, Engine=EasyOCR
# Processing lab report 422/426: MUM-0125-PA-0001141_W2500438UNADKAT ASHWIN_27-04-2025_1002-19_AM.pdf_page_118.png
# ✅ SUCCESS: Patient=Identifications
# Patient ID, Tests=1, Engine=EasyOCR
# Processing lab report 423/426: MUM-0425-PA-0003975_JAYANTILALA_27-04-2025_0319-39_PM.pdf_page_2.png
# ✅ SUCCESS: Patient=INVESTIGATION CHART
# Kapadia, Tests=13, Engine=EasyOCR
# Processing lab report 424/426: PUN-0425-PA-0011414_Lab Report_27-04-2025_0949-24_PM.pdf_page_11.png
# ✅ SUCCESS: Patient=ID
# Patient, Tests=6, Engine=EasyOCR
# Processing lab report 425/426: MUM-0125-PA-0001141_W2500438UNADKAT ASHWIN_27-04-2025_1001-12_AM.pdf_page_113.png
# ✅ SUCCESS: Patient=Identifications
# Patient IC, Tests=1, Engine=EasyOCR
# Processing lab report 426/426: RJT-0425-PA-0003571_H_24489_9286123311_52_00_REPORTOFDEVENDRA_28-04-2025_1158-13_AM@E.pdf_page_23.png
# ✅ SUCCESS: Patient=Primary Consultant, Tests=0, Engine=EasyOCR
#
# 📊 Lab Reports: 426/426 processed successfully
#
# 🔍 Processing Prescription Images...
# Found 129 prescription files
# Processing prescription 1/129: 113.jpg
# ✅ SUCCESS: Patient=Jab
# Lax, Meds=0, Engine=EasyOCR
# Processing prescription 2/129: 119.jpg
# ✅ SUCCESS: Patient=Female
# Urought
# YIUMOD, Meds=0, Engine=EasyOCR
# Processing prescription 3/129: 126.jpg
# ✅ SUCCESS: Patient=Aduress
# Ry, Meds=0, Engine=EasyOCR
# Processing prescription 4/129: 123.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=onan comme, Meds=0, Engine=Tesseract
# Processing prescription 5/129: 102.jpg
# ✅ SUCCESS: Patient=Lup
# Rtc, Meds=0, Engine=EasyOCR
# Processing prescription 6/129: 121.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=None, Meds=0, Engine=Tesseract
# Processing prescription 7/129: 128.jpg
# ✅ SUCCESS: Patient=HbsAg
# Urine, Meds=0, Engine=EasyOCR
# Processing prescription 8/129: 110.jpg
# ✅ SUCCESS: Patient=LIIL
# Kael, Meds=0, Engine=EasyOCR
# Processing prescription 9/129: 104.jpg
# ✅ SUCCESS: Patient=Narne of Consultant, Meds=0, Engine=EasyOCR
# Processing prescription 10/129: 127.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=roe eentltlOk, Meds=0, Engine=Tesseract
# Processing prescription 11/129: 100.jpg
# ✅ SUCCESS: Patient=Physician and Surgeon, Meds=0, Engine=EasyOCR
# Processing prescription 12/129: 116.jpg
# ✅ SUCCESS: Patient=kannoual
# cd, Meds=0, Engine=EasyOCR
# Processing prescription 13/129: 115.jpg
# ✅ SUCCESS: Patient=Pvt Ltd, Meds=0, Engine=EasyOCR
# Processing prescription 14/129: 109.jpg
# ✅ SUCCESS: Patient=Medicine
# MelX, Meds=0, Engine=EasyOCR
# Processing prescription 15/129: 12.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=ae eee
# SS, Meds=0, Engine=Tesseract
# Processing prescription 16/129: 1.jpg
# ❌ No meaningful text extracted from 1.jpg
# Processing prescription 17/129: 114.jpg
# ✅ SUCCESS: Patient=us Medical Arts
# WE Hansen, Meds=0, Engine=EasyOCR
# Processing prescription 18/129: 111.jpg
# ✅ SUCCESS: Patient=None, Meds=0, Engine=EasyOCR
# Processing prescription 19/129: 120.jpg
# ✅ SUCCESS: Patient=None, Meds=0, Engine=EasyOCR
# Processing prescription 20/129: 112.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=ne ne iF, Meds=0, Engine=Tesseract
# Processing prescription 21/129: 125.jpg
# ✅ SUCCESS: Patient=DTalt Arz, Meds=0, Engine=EasyOCR
# Processing prescription 22/129: 118.jpg
# ✅ SUCCESS: Patient=None, Meds=0, Engine=EasyOCR
# Processing prescription 23/129: 105.jpg
# ✅ SUCCESS: Patient=Sir Ganga Ram, Meds=1, Engine=EasyOCR
# Processing prescription 24/129: 101.jpg
# ✅ SUCCESS: Patient=Timings
# Days
# Afterioon, Meds=0, Engine=EasyOCR
# Processing prescription 25/129: 122.jpg
# ✅ SUCCESS: Patient=None, Meds=0, Engine=EasyOCR
# Processing prescription 26/129: 124.jpg
# ✅ SUCCESS: Patient=Emd
# Doctor
# Prescription
# Dalia Kundu
# Name, Meds=0, Engine=EasyOCR
# Processing prescription 27/129: 107.jpg
# ✅ SUCCESS: Patient=dieb
# HARRIMAN, Meds=0, Engine=EasyOCR
# Processing prescription 28/129: 11.jpg
# ✅ SUCCESS: Patient=ml
# Shwel
# ml, Meds=0, Engine=EasyOCR
# Processing prescription 29/129: 106.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=el ee
#
# oe, Meds=0, Engine=Tesseract
# Processing prescription 30/129: 10.jpg
# ✅ SUCCESS: Patient=CP
# GASYHOENTEROLOGY
# Apollo
# Consultant
# cel
# Regd No, Meds=0, Engine=EasyOCR
# Processing prescription 31/129: 108.jpg
# ✅ SUCCESS: Patient=Time
# SDWaSH
# UID, Meds=0, Engine=EasyOCR
# Processing prescription 32/129: 117.jpg
# ✅ SUCCESS: Patient=Omitted doses of, Meds=1, Engine=EasyOCR
# Processing prescription 33/129: 103.jpg
# ✅ SUCCESS: Patient=For
# wo, Meds=0, Engine=EasyOCR
# Processing prescription 34/129: 77.jpg
# ❌ No meaningful text extracted from 77.jpg
# Processing prescription 35/129: 76.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=BoE
# Mefrteee, Meds=0, Engine=Tesseract
# Processing prescription 36/129: 18.jpg
# ✅ SUCCESS: Patient=Address
# Ry, Meds=0, Engine=EasyOCR
# Processing prescription 37/129: 85.jpg
# ✅ SUCCESS: Patient=YLLE
# Doctor, Meds=0, Engine=EasyOCR
# Processing prescription 38/129: 42.jpg
# ✅ SUCCESS: Patient=ion by
# Klippa Medical Center
# Lubeckweg, Meds=2, Engine=EasyOCR
# Processing prescription 39/129: 95.jpg
# ✅ SUCCESS: Patient=Cons
# BABYRITI DUBEY, Meds=0, Engine=EasyOCR
# Processing prescription 40/129: 33.jpg
# ✅ SUCCESS: Patient=Veer Savarkar, Meds=1, Engine=EasyOCR
# Processing prescription 41/129: 44.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=ee Jd Lap, Meds=0, Engine=Tesseract
# Processing prescription 42/129: 57.jpg
# ✅ SUCCESS: Patient=None, Meds=0, Engine=EasyOCR
# Processing prescription 43/129: 2.jpg
# ✅ SUCCESS: Patient=Dald
# Hck Ge, Meds=0, Engine=EasyOCR
# Processing prescription 44/129: 73.jpg
# ✅ SUCCESS: Patient=No Known, Meds=0, Engine=EasyOCR
# Processing prescription 45/129: 4.jpg
# ✅ SUCCESS: Patient=yiomiod
# Category
# General, Meds=0, Engine=EasyOCR
# Processing prescription 46/129: 26.jpg
# ❌ No meaningful text extracted from 26.jpg
# Processing prescription 47/129: 93.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=None, Meds=0, Engine=Tesseract
# Processing prescription 48/129: 67.jpg
# ✅ SUCCESS: Patient=Tmo
# Phone No, Meds=0, Engine=EasyOCR
# Processing prescription 49/129: 81.jpg
# ✅ SUCCESS: Patient=MBBS DCHMD, Meds=0, Engine=EasyOCR
# Processing prescription 50/129: 36.jpg
# ✅ SUCCESS: Patient=SumDra
# gole, Meds=0, Engine=EasyOCR
# Processing prescription 51/129: 43.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=Piet oe See, Meds=0, Engine=Tesseract
# Processing prescription 52/129: 71.jpg
# ✅ SUCCESS: Patient=RADIO
# Stamp, Meds=0, Engine=EasyOCR
# Processing prescription 53/129: 39.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=roe is, Meds=0, Engine=Tesseract
# Processing prescription 54/129: 13.jpg
# ✅ SUCCESS: Patient=PHARMACEUTICAL BENEFITS ENTITLEMENT, Meds=0, Engine=EasyOCR
# Processing prescription 55/129: 24.jpg
# ✅ SUCCESS: Patient=Dr Raja
# Nag, Meds=0, Engine=EasyOCR
# Processing prescription 56/129: 29.jpg
# ✅ SUCCESS: Patient=ION
# UsN
# forgotten, Meds=0, Engine=EasyOCR
# Processing prescription 57/129: 6.jpg
# ✅ SUCCESS: Patient=Primus
# Super Speciality, Meds=0, Engine=EasyOCR
# Processing prescription 58/129: 20.jpg
# ✅ SUCCESS: Patient=MIDTOWN PARK PHARMACY, Meds=0, Engine=EasyOCR
# Processing prescription 59/129: 63.jpg
# ✅ SUCCESS: Patient=Co
# Tcst, Meds=0, Engine=EasyOCR
# Processing prescription 60/129: 7.jpg
# ✅ SUCCESS: Patient=Eibz Sex
# Age, Meds=0, Engine=EasyOCR
# Processing prescription 61/129: 70.jpg
# ❌ No meaningful text extracted from 70.jpg
# Processing prescription 62/129: 19.jpg
# ✅ SUCCESS: Patient=ole Fo
# Ca, Meds=0, Engine=EasyOCR
# Processing prescription 63/129: 88.jpg
# ✅ SUCCESS: Patient=Confirming
# RADIO
# USA, Meds=0, Engine=EasyOCR
# Processing prescription 64/129: 28.jpg
# ✅ SUCCESS: Patient=Nanavati
# Super Speciality, Meds=0, Engine=EasyOCR
# Processing prescription 65/129: 17.jpg
# ✅ SUCCESS: Patient=CJHItE TUSK
# Smile, Meds=0, Engine=EasyOCR
# Processing prescription 66/129: 56.jpg
# ✅ SUCCESS: Patient=NO Refills
# ido, Meds=0, Engine=EasyOCR
# Processing prescription 67/129: 66.jpg
# ✅ SUCCESS: Patient=Govt of Natonal, Meds=0, Engine=EasyOCR
# Processing prescription 68/129: 99.jpg
# ✅ SUCCESS: Patient=revtld
# Tmau, Meds=0, Engine=EasyOCR
# Processing prescription 69/129: 16.jpg
# ✅ SUCCESS: Patient=Miedicine
# facacETAMO
# Dox, Meds=0, Engine=EasyOCR
# Processing prescription 70/129: 50.jpg
# ✅ SUCCESS: Patient=at
# ylo mth, Meds=0, Engine=EasyOCR
# Processing prescription 71/129: 65.jpg
# ✅ SUCCESS: Patient=Surg
# MANILA Doctore, Meds=0, Engine=EasyOCR
# Processing prescription 72/129: 79.jpg
# ✅ SUCCESS: Patient=GoRorDo AVENUE, Meds=0, Engine=EasyOCR
# Processing prescription 73/129: 82.jpg
# ✅ SUCCESS: Patient=IWaist Circum, Meds=0, Engine=EasyOCR
# Processing prescription 74/129: 74.jpg
# ✅ SUCCESS: Patient=Jayaprakash Hebbar
# MBBS, Meds=0, Engine=EasyOCR
# Processing prescription 75/129: 64.jpg
# ✅ SUCCESS: Patient=kandwthing
# anyting, Meds=0, Engine=EasyOCR
# Processing prescription 76/129: 5.jpg
# ✅ SUCCESS: Patient=tw Ce, Meds=0, Engine=EasyOCR
# Processing prescription 77/129: 14.jpg
# ✅ SUCCESS: Patient=YOURGP
# DRI, Meds=0, Engine=EasyOCR
# Processing prescription 78/129: 38.jpg
# ✅ SUCCESS: Patient=ion
# Shila Dasgupta
# Dr, Meds=0, Engine=EasyOCR
# Processing prescription 79/129: 97.jpg
# ✅ SUCCESS: Patient=AGE
# Exam, Meds=1, Engine=EasyOCR
# Processing prescription 80/129: 8.jpg
# ✅ SUCCESS: Patient=Kltlo
# Om
# Kin, Meds=0, Engine=EasyOCR
# Processing prescription 81/129: 58.jpg
# ✅ SUCCESS: Patient=RB Toru kd, Meds=1, Engine=EasyOCR
# Processing prescription 82/129: 96.jpg
# ✅ SUCCESS: Patient=Kevin Zadnick
# Address, Meds=0, Engine=EasyOCR
# Processing prescription 83/129: 94.jpg
# ✅ SUCCESS: Patient=Hopital Fleurimont
# Hotel, Meds=0, Engine=EasyOCR
# Processing prescription 84/129: 52.jpg
# ✅ SUCCESS: Patient=Tealth Sucietp, Meds=0, Engine=EasyOCR
# Processing prescription 85/129: 62.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=foal ty, Meds=0, Engine=Tesseract
# Processing prescription 86/129: 21.jpg
# ✅ SUCCESS: Patient=ny
# daus
# albout, Meds=0, Engine=EasyOCR
# Processing prescription 87/129: 84.jpg
# ✅ SUCCESS: Patient=Khawar
# Dr, Meds=0, Engine=EasyOCR
# Processing prescription 88/129: 40.jpg
# ✅ SUCCESS: Patient=AmGtsome
# Zov, Meds=0, Engine=EasyOCR
# Processing prescription 89/129: 59.jpg
# ✅ SUCCESS: Patient=Adv
# wam Bolue, Meds=0, Engine=EasyOCR
# Processing prescription 90/129: 46.jpg
# ✅ SUCCESS: Patient=AIG
# Mindspace, Meds=0, Engine=EasyOCR
# Processing prescription 91/129: 35.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=piesa al he, Meds=0, Engine=Tesseract
# Processing prescription 92/129: 22.jpg
# ✅ SUCCESS: Patient=WILLIAM LEWIS, Meds=0, Engine=EasyOCR
# Processing prescription 93/129: 55.jpg
# ✅ SUCCESS: Patient=Mquazk
# dp, Meds=0, Engine=EasyOCR
# Processing prescription 94/129: 89.jpg
# ✅ SUCCESS: Patient=ODESSA TEXAS
# FOR, Meds=0, Engine=EasyOCR
# Processing prescription 95/129: 53.jpg
# ✅ SUCCESS: Patient=acement
# DMC NO, Meds=0, Engine=EasyOCR
# Processing prescription 96/129: 61.jpg
# ✅ SUCCESS: Patient=Hopital Fleurimont
# Hotel, Meds=0, Engine=EasyOCR
# Processing prescription 97/129: 9.jpg
# ✅ SUCCESS: Patient=Day
# Is mL, Meds=1, Engine=EasyOCR
# Processing prescription 98/129: 68.jpg
# ✅ SUCCESS: Patient=ACOzQ
# Affix
# UbBHz, Meds=0, Engine=EasyOCR
# Processing prescription 99/129: 32.jpg
# ✅ SUCCESS: Patient=Road
# TYNG
# Oiodliioo, Meds=0, Engine=EasyOCR
# Processing prescription 100/129: 45.jpg
# ✅ SUCCESS: Patient=ation Scedule, Meds=0, Engine=EasyOCR
# Processing prescription 101/129: 41.jpg
# ❌ No meaningful text extracted from 41.jpg
# Processing prescription 102/129: 86.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=Ea
# PA MZ, Meds=0, Engine=Tesseract
# Processing prescription 103/129: 78.jpg
# ✅ SUCCESS: Patient=Delu
# Aml
# Tr, Meds=0, Engine=EasyOCR
# Processing prescription 104/129: 27.jpg
# ✅ SUCCESS: Patient=EW
# Gr, Meds=0, Engine=EasyOCR
# Processing prescription 105/129: 83.jpg
# ✅ SUCCESS: Patient=us Medical Arts
# WE Hansen, Meds=0, Engine=EasyOCR
# Processing prescription 106/129: 129.jpg
# ❌ No meaningful text extracted from 129.jpg
# Processing prescription 107/129: 51.jpg
# ✅ SUCCESS: Patient=Jsm nu slaik, Meds=0, Engine=EasyOCR
# Processing prescription 108/129: 49.jpg
# ✅ SUCCESS: Patient=None, Meds=0, Engine=EasyOCR
# Processing prescription 109/129: 90.jpg
# ❌ No meaningful text extracted from 90.jpg
# Processing prescription 110/129: 47.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=None, Meds=0, Engine=Tesseract
# Processing prescription 111/129: 3.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=Se ee
# Noocascen, Meds=0, Engine=Tesseract
# Processing prescription 112/129: 92.jpg
# ✅ SUCCESS: Patient=Lposowal
# IV, Meds=0, Engine=EasyOCR
# Processing prescription 113/129: 54.jpg
# ✅ SUCCESS: Patient=EB FAIRVIEW, Meds=0, Engine=EasyOCR
# Processing prescription 114/129: 34.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=oe ug, Meds=0, Engine=Tesseract
# Processing prescription 115/129: 75.jpg
# ✅ SUCCESS: Patient=dan
# Auun, Meds=0, Engine=EasyOCR
# Processing prescription 116/129: 25.jpg
# ✅ SUCCESS: Patient=ION DEPARTMENT
# colukbub, Meds=0, Engine=EasyOCR
# Processing prescription 117/129: 60.jpg
# ✅ SUCCESS: Patient=isesa
# Heg
# Patient Name
# Corporate
# MRD, Meds=0, Engine=EasyOCR
# Processing prescription 118/129: 72.jpg
# ✅ SUCCESS: Patient=Rx
# Zab, Meds=0, Engine=EasyOCR
# Processing prescription 119/129: 23.jpg
# ✅ SUCCESS: Patient=Iwuk
# brn stake, Meds=0, Engine=EasyOCR
# Processing prescription 120/129: 48.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=aie WP, Meds=0, Engine=Tesseract
# Processing prescription 121/129: 31.jpg
# ✅ SUCCESS: Patient=Alan Johnson, Meds=0, Engine=EasyOCR
# Processing prescription 122/129: 30.jpg
# ✅ SUCCESS: Patient=CJHItE TUSK
# THE, Meds=1, Engine=EasyOCR
# Processing prescription 123/129: 87.jpg
# ✅ SUCCESS: Patient=Cyror
# Pancreas
# RDI, Meds=0, Engine=EasyOCR
# Processing prescription 124/129: 37.jpg
# ✅ SUCCESS: Patient=Phyaician and Surrcon, Meds=0, Engine=EasyOCR
# Processing prescription 125/129: 80.jpg
# ✅ SUCCESS: Patient=Gnukon
# Tr
# Jk, Meds=0, Engine=EasyOCR
# Processing prescription 126/129: 69.jpg
# PaddleOCR failed: PaddleOCR.predict() got an unexpected keyword argument 'cls'
# ✅ SUCCESS: Patient=asec eae fel, Meds=0, Engine=Tesseract
# Processing prescription 127/129: 98.jpg
# ✅ SUCCESS: Patient=PRESCRIPTION
# Memorial Hospltal, Meds=0, Engine=EasyOCR
# Processing prescription 128/129: 15.jpg
# ✅ SUCCESS: Patient=Doctors Urgent Care, Meds=0, Engine=EasyOCR
# Processing prescription 129/129: 91.jpg
# ✅ SUCCESS: Patient=Salivari Glands, Meds=0, Engine=EasyOCR
#
# 📊 Prescriptions: 122/129 processed successfully
#
# 📊 FINAL PROCESSING SUMMARY:
# Total documents processed: 548
# Lab reports: 426
# Prescriptions: 122
# Knowledge graph nodes: 2712
# Knowledge graph edges: 3837
#
# 🔧 OCR Engine Usage:
#   EasyOCR: 529 documents
#   Tesseract: 19 documents
#
# 💾 Documents saved to: /content/output/processed_documents_robust.json
# ✅ ROBUST MEDICAL RAG SYSTEM READY!

# %%
# RAG System Module with Sentence Transformers
from sentence_transformers import SentenceTransformer
import faiss

class MedicalRAGSystem:
    def __init__(self, knowledge_graph):
        self.kg = knowledge_graph
        print(" Loading sentence transformer model...")
        self.embedder = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
        self.document_chunks = []
        self.chunk_embeddings = None
        self.faiss_index = None
        print("RAG embedder initialized")

    def index_documents(self, processed_documents):
        """Create vector index for document retrieval"""
        print("Creating document chunks and embeddings...")
        self.document_chunks = []
        chunk_texts = []

        for doc in processed_documents:
            chunks = self._chunk_text(doc.get('raw_text', ''), chunk_size=300)
            for i, chunk in enumerate(chunks):
                if len(chunk.strip()) > 20:  # Only index meaningful chunks
                    chunk_data = {
                        'text': chunk,
                        'document_type': doc.get('document_type'),
                        'patient_name': doc.get('patient_name'),
                        'date': doc.get('date'),
                        'chunk_id': f"{doc.get('patient_name', 'unknown')}_{i}",
                        'source_doc': doc,
                        'ocr_engine': doc.get('ocr_engine', 'Unknown'),
                        'confidence': doc.get('confidence_score', 0)
                    }
                    self.document_chunks.append(chunk_data)
                    chunk_texts.append(chunk)

        if chunk_texts:
            print(f"Creating embeddings for {len(chunk_texts)} chunks...")
            embeddings = self.embedder.encode(chunk_texts, show_progress_bar=True)
            self.chunk_embeddings = np.array(embeddings)

            # Create FAISS index
            dimension = embeddings.shape[1]
            self.faiss_index = faiss.IndexFlatIP(dimension)  # Inner product for cosine similarity

            # Normalize embeddings for cosine similarity
            faiss.normalize_L2(self.chunk_embeddings)
            self.faiss_index.add(self.chunk_embeddings)
            print(f" FAISS index created with {len(chunk_texts)} vectors")
        else:
            print(" No meaningful chunks to index!")

    def _chunk_text(self, text, chunk_size=300, overlap=50):
        """Split text into overlapping chunks"""
        words = text.split()
        chunks = []

        for i in range(0, len(words), chunk_size - overlap):
            chunk = ' '.join(words[i:i + chunk_size])
            if chunk.strip():
                chunks.append(chunk)

        return chunks

    def retrieve_relevant_chunks(self, query, top_k=5):
        """Retrieve relevant document chunks using semantic search"""
        if self.faiss_index is None:
            return []

        # Encode query
        query_embedding = self.embedder.encode([query])
        faiss.normalize_L2(query_embedding)

        # Search
        scores, indices = self.faiss_index.search(query_embedding, top_k)

        results = []
        for score, idx in zip(scores[0], indices[0]):
            if idx < len(self.document_chunks) and idx != -1:
                chunk = self.document_chunks[idx].copy()
                chunk['relevance_score'] = float(score)
                results.append(chunk)

        return results

    def query_knowledge_graph(self, query):
        """Query knowledge graph for structured information"""
        query_lower = query.lower()

        # Patient history queries
        if any(word in query_lower for word in ['history', 'patient', 'records', 'timeline']):
            words = query.split()
            potential_names = [w for w in words if len(w) > 2 and w[0].isupper()]

            if potential_names:
                patient_name = ' '.join(potential_names[:2])
                return self.kg.query_patient_history(patient_name)

        # Medication pattern queries
        elif any(word in query_lower for word in ['prescription', 'medication', 'drug', 'medicine', 'common']):
            return self.kg.query_medication_patterns()

        # Lab test queries
        elif any(word in query_lower for word in ['lab', 'test', 'result', 'abnormal', 'blood']):
            return self.kg.query_lab_patterns()

        return {"message": "No specific KG query pattern matched"}

    def generate_answer(self, query):
        """Generate comprehensive answer using RAG approach"""
        print(f"🔍 Processing query: '{query}'")

        # Step 1: Retrieve relevant chunks
        relevant_chunks = self.retrieve_relevant_chunks(query, top_k=5)

        # Step 2: Query knowledge graph
        kg_results = self.query_knowledge_graph(query)

        # Step 3: Combine and format response
        response = {
            'query': query,
            'kg_results': kg_results,
            'relevant_chunks': relevant_chunks,
            'answer': self._format_answer(query, kg_results, relevant_chunks),
            'metadata': {
                'chunks_found': len(relevant_chunks),
                'kg_pattern_matched': kg_results.get('message') != "No specific KG query pattern matched",
                'avg_relevance_score': np.mean([c.get('relevance_score', 0) for c in relevant_chunks]) if relevant_chunks else 0
            }
        }

        return response

    def _format_answer(self, query, kg_results, chunks):
        """Format final answer from retrieved information"""
        answer_parts = []

        # Add Knowledge Graph insights
        if 'patient_name' in kg_results:
            patient_name = kg_results['patient_name']
            prescriptions = kg_results.get('prescriptions', [])
            lab_results = kg_results.get('lab_results', [])

            answer_parts.append(f"**Medical History for {patient_name}:**")

            if prescriptions:
                answer_parts.append(f"📋 Found {len(prescriptions)} prescription records:")
                for i, presc in enumerate(prescriptions[:3], 1):
                    medications = ', '.join([med['name'] for med in presc.get('medications', [])])
                    date_str = presc.get('date', 'Unknown date')
                    prescriber = presc.get('prescriber', 'Unknown prescriber')
                    answer_parts.append(f"  {i}. **Date:** {date_str} | **Prescriber:** {prescriber}")
                    answer_parts.append(f"     **Medications:** {medications}")

            if lab_results:
                answer_parts.append(f" Lab Results: {len(lab_results)} tests found")

        elif 'common_medications' in kg_results:
            meds = kg_results['common_medications']
            total = kg_results['total_prescriptions']

            answer_parts.append(f"**Medication Analysis from {total} prescriptions:**")
            answer_parts.append("**Most commonly prescribed medications:**")

            for i, (med, count) in enumerate(meds[:5], 1):
                percentage = (count / total * 100) if total > 0 else 0
                answer_parts.append(f"  {i}. **{med}**: {count} prescriptions ({percentage:.1f}%)")

        elif 'common_tests' in kg_results:
            tests = kg_results['common_tests']
            answer_parts.append(" **Most common lab tests:**")
            for i, (test, count) in enumerate(tests[:5], 1):
                answer_parts.append(f"  {i}. **{test}**: {count} occurrences")

        # Add relevant document excerpts
        if chunks:
            answer_parts.append(f"\n **Supporting Evidence from Documents:**")
            for i, chunk in enumerate(chunks[:3], 1):
                relevance = chunk.get('relevance_score', 0)
                doc_type = chunk.get('document_type', 'document').title()
                patient = chunk.get('patient_name', 'Unknown patient')
                engine = chunk.get('ocr_engine', 'Unknown')

                answer_parts.append(f"**{i}. {doc_type}** (Patient: {patient}, OCR: {engine}, Relevance: {relevance:.3f})")
                text_preview = chunk['text'][:200].replace('\n', ' ')
                answer_parts.append(f"   _{text_preview}..._")

        # Add metadata about search quality
        if chunks:
            avg_relevance = np.mean([c.get('relevance_score', 0) for c in chunks])
            answer_parts.append(f"\n**Search Quality:** Average relevance score: {avg_relevance:.3f}")

        return '\n'.join(answer_parts) if answer_parts else "No relevant information found in the processed documents."

# Add query_patient_history and query_lab_patterns methods to KnowledgeGraph
def add_missing_kg_methods():
    """Add missing methods to the knowledge graph"""

    def query_patient_history(self, patient_name):
        """Query patient's medical history"""
        patient_key = f"patient_{patient_name.lower()}"
        patient_ids = self.entity_index.get(patient_key, [])

        if not patient_ids:
            return {"error": f"Patient {patient_name} not found"}

        patient_id = patient_ids[0]
        history = {
            'patient_name': patient_name,
            'prescriptions': [],
            'lab_results': [],
            'diagnoses': []
        }

        # Get prescriptions
        for neighbor in self.graph.successors(patient_id):
            node_data = self.graph.nodes[neighbor]
            if node_data.get('type') == 'prescription':
                medications = []
                for med_neighbor in self.graph.successors(neighbor):
                    med_data = self.graph.nodes[med_neighbor]
                    if med_data.get('type') == 'medication':
                        edge_data = self.graph.get_edge_data(neighbor, med_neighbor)
                        medications.append({
                            'name': med_data.get('name'),
                            'dosage': list(edge_data.values())[0].get('dosage')
                        })

                history['prescriptions'].append({
                    'date': node_data.get('date'),
                    'prescriber': node_data.get('prescriber'),
                    'medications': medications
                })

            elif node_data.get('type') == 'encounter':
                # Get lab results for this encounter
                for result_neighbor in self.graph.successors(neighbor):
                    result_data = self.graph.nodes[result_neighbor]
                    if result_data.get('type') == 'lab_result':
                        history['lab_results'].append({
                            'value': result_data.get('value'),
                            'unit': result_data.get('unit'),
                            'date': result_data.get('date')
                        })

        return history

    def query_lab_patterns(self):
        """Query common lab test patterns"""
        patterns = defaultdict(int)
        test_nodes = [n for n, d in self.graph.nodes(data=True) if d.get('type') == 'lab_test']

        for test_id in test_nodes:
            test_data = self.graph.nodes[test_id]
            test_name = test_data.get('name')
            if test_name:
                patterns[test_name] += 1

        sorted_patterns = sorted(patterns.items(), key=lambda x: x[1], reverse=True)
        return {
            'common_tests': sorted_patterns[:10],
            'total_tests': len(test_nodes)
        }

    # Add methods to the class
    MedicalKnowledgeGraph.query_patient_history = query_patient_history
    MedicalKnowledgeGraph.query_lab_patterns = query_lab_patterns

# Apply the missing methods
add_missing_kg_methods()

# Initialize RAG system if documents were processed successfully
if 'processed_docs' in locals() and processed_docs:
    print(" Initializing RAG System...")
    rag_system = MedicalRAGSystem(kg)
    rag_system.index_documents(processed_docs)
    print("RAG System ready for queries!")
else:
    print("No processed documents found. Run the processing pipeline first.")
    rag_system = None
# Out:
#  Initializing RAG System...
#  Loading sentence transformer model...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# RAG embedder initialized
# Creating document chunks and embeddings...
# Creating embeddings for 583 chunks...
# Batches:   0%|          | 0/19 [00:00<?, ?it/s]
#  FAISS index created with 583 vectors
# RAG System ready for queries!

# %%
# Complete Interactive Demo System
def run_comprehensive_medical_rag_demo():
    """Run comprehensive demonstration of the medical RAG system"""

    if not processed_docs:
        print(" No processed documents found! Run the processing pipeline first.")
        return

    print("COMPREHENSIVE MEDICAL RAG SYSTEM DEMONSTRATION")
    print("=" * 60)

    # System Statistics
    print(f"\n **SYSTEM OVERVIEW:**")
    print(f"    Total documents processed: {len(processed_docs)}")
    print(f"    Lab reports: {sum(1 for doc in processed_docs if doc['document_type'] == 'lab_report')}")
    print(f"   Prescriptions: {sum(1 for doc in processed_docs if doc['document_type'] == 'prescription')}")
    print(f"    Knowledge graph nodes: {kg.graph.number_of_nodes()}")
    print(f"    Knowledge graph edges: {kg.graph.number_of_edges()}")
    print(f"    Vector index size: {len(rag_system.document_chunks) if rag_system else 0}")

    # OCR Engine Statistics
    engine_stats = defaultdict(int)
    confidence_scores = []
    for doc in processed_docs:
        engine_stats[doc.get('ocr_engine', 'Unknown')] += 1
        if doc.get('confidence_score'):
            confidence_scores.append(doc['confidence_score'])

    print(f"\n **OCR ENGINE PERFORMANCE:**")
    for engine, count in engine_stats.items():
        percentage = (count / len(processed_docs)) * 100
        print(f"   {engine}: {count} documents ({percentage:.1f}%)")

    if confidence_scores:
        avg_confidence = sum(confidence_scores) / len(confidence_scores)
        print(f"   📈 Average OCR confidence: {avg_confidence:.3f}")

    # Demo Queries
    demo_queries = [
        "What are the most commonly prescribed medications?",
        "Show me lab test results and abnormal values",
        "List all patients found in the documents",
        "Find medications with dosage information",
        "Show me diabetes related prescriptions"
    ]

    print(f"\n **RUNNING DEMO QUERIES:**")

    for i, query in enumerate(demo_queries, 1):
        print(f"\n{'='*50}")
        print(f" **Demo Query {i}:** {query}")
        print("-" * 30)

        try:
            response = rag_system.generate_answer(query)
            print(response['answer'])

            # Show metadata
            metadata = response.get('metadata', {})
            print(f"\n **Query Metadata:**")
            print(f"   Chunks found: {metadata.get('chunks_found', 0)}")
            print(f"   KG pattern matched: {metadata.get('kg_pattern_matched', False)}")
            print(f"   Avg relevance: {metadata.get('avg_relevance_score', 0):.3f}")

        except Exception as e:
            print(f" **Error:** {str(e)}")

    # Show Knowledge Graph Insights
    print(f"\n **KNOWLEDGE GRAPH INSIGHTS:**")
    try:
        med_patterns = kg.query_medication_patterns()
        if med_patterns.get('common_medications'):
            print(f" **Top 5 Medications Found:**")
            for i, (med, count) in enumerate(med_patterns['common_medications'][:5], 1):
                print(f"   {i}. {med} ({count} prescriptions)")

        lab_patterns = kg.query_lab_patterns()
        if lab_patterns.get('common_tests'):
            print(f"\n**Top 5 Lab Tests Found:**")
            for i, (test, count) in enumerate(lab_patterns['common_tests'][:5], 1):
                print(f"   {i}. {test} ({count} occurrences)")
    except Exception as e:
        print(f"Error getting insights: {e}")

    # Show Sample Extracted Data
    print(f"\n **SAMPLE EXTRACTED DATA:**")

    # Show sample patients
    patient_names = set()
    for doc in processed_docs:
        if doc.get('patient_name') and doc['patient_name'] not in ['Unknown', None]:
            patient_names.add(doc['patient_name'])

    if patient_names:
        print(f"👥 **Unique Patients Found:** {len(patient_names)}")
        for name in list(patient_names)[:5]:
            print(f"   - {name}")

    # Show sample medications
    all_medications = set()
    for doc in processed_docs:
        if doc['document_type'] == 'prescription':
            for med in doc.get('medications', []):
                if med.get('name'):
                    all_medications.add(med['name'])

    if all_medications:
        print(f"\n**Sample Medications Found:** {len(all_medications)} unique")
        for med in list(all_medications)[:5]:
            print(f"   - {med}")

    # Show sample lab tests
    all_tests = set()
    for doc in processed_docs:
        if doc['document_type'] == 'lab_report':
            for test in doc.get('lab_tests', []):
                if test.get('test_name'):
                    all_tests.add(test['test_name'])

    if all_tests:
        print(f"\n **Sample Lab Tests Found:** {len(all_tests)} unique")
        for test in list(all_tests)[:5]:
            print(f"   - {test}")

    print(f"\n **DEMO COMPLETE!**")

    return True

# Interactive Query Interface
def run_interactive_medical_queries():
    """Interactive query interface for the medical RAG system"""

    if not rag_system:
        print(" RAG system not initialized! Run the processing pipeline first.")
        return

    print("\n💬 **INTERACTIVE MEDICAL RAG QUERY SYSTEM**")
    print("=" * 50)

    print("📋 **Sample queries you can try:**")
    sample_queries = [
        "What medications were prescribed for diabetes?",
        "Show me abnormal lab test results",
        "List all patients with their medical history",
        "Find prescriptions with specific dosages",
        "Show me blood sugar test results",
        "What are the common diagnoses found?",
        "Find patients prescribed Metformin",
        "Show me recent lab reports"
    ]

    for i, query in enumerate(sample_queries, 1):
        print(f"   {i}. {query}")

    print(f"\n{'='*50}")
    print(" **Tips:**")
    print("   - Ask about specific patients by name")
    print("   - Search for medication patterns and trends")
    print("   - Query lab test results and abnormal values")
    print("   - Look for relationships between tests and prescriptions")
    print("   - Type 'stats' to see system statistics")
    print("   - Type 'quit' to exit")
    print(f"{'='*50}")

    query_count = 0
    while True:
        try:
            print(f"\n **Enter your medical query:**")
            user_query = input("🔍 Query: ").strip()

            if user_query.lower() in ['quit', 'exit', 'q']:
                print(" Goodbye! Thanks for using the Medical RAG System!")
                break

            if not user_query:
                print(" Please enter a query")
                continue

            if user_query.lower() == 'stats':
                print(f"\n**SYSTEM STATISTICS:**")
                print(f"   Documents processed: {len(processed_docs)}")
                print(f"   Knowledge graph nodes: {kg.graph.number_of_nodes()}")
                print(f"   Vector chunks indexed: {len(rag_system.document_chunks)}")
                print(f"   Queries processed: {query_count}")
                continue

            query_count += 1
            print(f"\n **Processing query #{query_count}...**")
            print("-" * 40)

            # Generate answer
            response = rag_system.generate_answer(user_query)

            print(f"📋 **Answer:**")
            print(response['answer'])

            # Show additional information
            metadata = response.get('metadata', {})
            if metadata.get('chunks_found', 0) > 0:
                print(f"\n **Search Results:**")
                print(f"    Document chunks found: {metadata['chunks_found']}")
                print(f"    Average relevance score: {metadata.get('avg_relevance_score', 0):.3f}")
                print(f"    Knowledge graph used: {'Yes' if metadata.get('kg_pattern_matched') else 'No'}")

                # Show top relevant chunks
                chunks = response.get('relevant_chunks', [])
                if chunks:
                    print(f"\n📄 **Top Sources:**")
                    for i, chunk in enumerate(chunks[:2], 1):
                        doc_type = chunk.get('document_type', 'document').title()
                        patient = chunk.get('patient_name', 'Unknown')
                        score = chunk.get('relevance_score', 0)
                        print(f"   {i}. {doc_type} (Patient: {patient}, Score: {score:.3f})")

        except KeyboardInterrupt:
            print(f"\n\n Session interrupted. Goodbye!")
            break
        except Exception as e:
            print(f" **Error processing query:** {str(e)}")
            print("Please try a different query.")

# Export and Save Functions
def export_results():
    """Export processed results to various formats"""

    if not processed_docs:
        print(" No processed documents to export!")
        return

    print("💾 **EXPORTING RESULTS...**")

    try:
        # Export processed documents
        with open('/content/output/processed_documents_complete.json', 'w') as f:
            json.dump(processed_docs, f, indent=2, default=str)
        print(f" Processed documents: /content/output/processed_documents_complete.json")

        # Export knowledge graph data
        graph_data = kg.export_graph_data()
        with open('/content/output/knowledge_graph_data.json', 'w') as f:
            json.dump(graph_data, f, indent=2, default=str)
        print(f"Knowledge graph: /content/output/knowledge_graph_data.json")

        # Export summary statistics
        stats = {
            'processing_summary': {
                'total_documents': len(processed_docs),
                'lab_reports': sum(1 for doc in processed_docs if doc['document_type'] == 'lab_report'),
                'prescriptions': sum(1 for doc in processed_docs if doc['document_type'] == 'prescription'),
                'processing_date': datetime.now().isoformat()
            },
            'knowledge_graph_stats': {
                'total_nodes': kg.graph.number_of_nodes(),
                'total_edges': kg.graph.number_of_edges(),
            },
            'extraction_insights': {
                'unique_patients': len(set(doc.get('patient_name') for doc in processed_docs if doc.get('patient_name') and doc['patient_name'] != 'Unknown')),
                'total_medications': sum(len(doc.get('medications', [])) for doc in processed_docs if doc['document_type'] == 'prescription'),
                'total_lab_tests': sum(len(doc.get('lab_tests', [])) for doc in processed_docs if doc['document_type'] == 'lab_report')
            }
        }

        with open('/content/output/system_statistics.json', 'w') as f:
            json.dump(stats, f, indent=2, default=str)
        print(f"System statistics: /content/output/system_statistics.json")

        print(f"\n **All results exported to /content/output/ directory**")

    except Exception as e:
        print(f"Export error: {str(e)}")

# Missing export_graph_data method for KnowledgeGraph
def export_graph_data(self):
    """Export graph for visualization and analysis"""
    nodes = []
    edges = []

    for node_id, data in self.graph.nodes(data=True):
        nodes.append({
            'id': node_id,
            'type': data.get('type', 'unknown'),
            'name': data.get('name', node_id),
            **{k: v for k, v in data.items() if k not in ['id', 'type', 'name']}
        })

    for source, target, data in self.graph.edges(data=True):
        edges.append({
            'source': source,
            'target': target,
            'relation': data.get('relation', 'connected'),
            **{k: v for k, v in data.items() if k not in ['source', 'target', 'relation']}
        })

    return {'nodes': nodes, 'edges': edges}

# Add the method to the class
MedicalKnowledgeGraph.export_graph_data = export_graph_data

print(" **MEDICAL RAG SYSTEM COMPLETE!**")
print("\n **Ready to use! Try these commands:**")
print("   - run_comprehensive_medical_rag_demo()  # Run full demo")
print("   - run_interactive_medical_queries()     # Interactive chat")
print("   - export_results()                      # Save all results")
# Out:
#  **MEDICAL RAG SYSTEM COMPLETE!**
#
#  **Ready to use! Try these commands:**
#    - run_comprehensive_medical_rag_demo()  # Run full demo
#    - run_interactive_medical_queries()     # Interactive chat
#    - export_results()                      # Save all results

# %%
run_interactive_medical_queries()
# Out:
# 💬 **INTERACTIVE MEDICAL RAG QUERY SYSTEM**
# ==================================================
# 📋 **Sample queries you can try:**
#    1. What medications were prescribed for diabetes?
#    2. Show me abnormal lab test results
#    3. List all patients with their medical history
#    4. Find prescriptions with specific dosages
#    5. Show me blood sugar test results
#    6. What are the common diagnoses found?
#    7. Find patients prescribed Metformin
#    8. Show me recent lab reports
#
# ==================================================
#  **Tips:**
#    - Ask about specific patients by name
#    - Search for medication patterns and trends
#    - Query lab test results and abnormal values
#    - Look for relationships between tests and prescriptions
#    - Type 'stats' to see system statistics
#    - Type 'quit' to exit
# ==================================================
#
#  **Enter your medical query:**
# 🔍 Query:  What medications were prescribed for diabetes?
#
#  **Processing query #1...**
# ----------------------------------------
# 🔍 Processing query: 'What medications were prescribed for diabetes?'
# 📋 **Answer:**
# **Medication Analysis from 122 prescriptions:**
# **Most commonly prescribed medications:**
#   1. **TAB**: 1 prescriptions (0.8%)
#   2. **insulin**: 1 prescriptions (0.8%)
#   3. **Paracetamol**: 1 prescriptions (0.8%)
#   4. **Ibuprofen**: 1 prescriptions (0.8%)
#   5. **fuuide**: 1 prescriptions (0.8%)
#
#  **Supporting Evidence from Documents:**
# **1. Prescription** (Patient: Omitted doses of, OCR: EasyOCR, Relevance: 0.479)
#    _ofinsl Pharmacy] Signa; 210 Omitted doses of insulin..._
# **2. Lab_Report** (Patient: RESULT
# UNIT, OCR: EasyOCR, Relevance: 0.396)
#    _care you can trustTM SITARAM BHARTIA Institute of Science & Research LABORATORY INVESTIGATION REPORT Patient] SBID.325941 UHId 1515162 Episode IP Dr. Medicine Unit /Pradeep Narayan Chauhan Ref: Doctor..._
# **3. Lab_Report** (Patient: orns   is
# Random   plasma   glucoso
# Interprelations, OCR: EasyOCR, Relevance: 0.390)
#    _AIG HOSPITALS LABORATORY INVESTIGATION REPORT 32 Year(s)Malc Age/ Sex Patient h0:16 Order Date AIGG.20968030 UHID AGOCS250375793 Bill No. OP Episode Mobile No Dr. Siddhant Matnur Ref. Doctor AIG Hospi..._
#
# **Search Quality:** Average relevance score: 0.400
#
#  **Search Results:**
#     Document chunks found: 5
#     Average relevance score: 0.400
#     Knowledge graph used: Yes
#
# 📄 **Top Sources:**
#    1. Prescription (Patient: Omitted doses of, Score: 0.479)
#    2. Lab_Report (Patient: RESULT
# UNIT, Score: 0.396)
#
#  **Enter your medical query:**
# 🔍 Query: Find patients prescribed Metformin
#
#  **Processing query #2...**
# ----------------------------------------
# 🔍 Processing query: 'Find patients prescribed Metformin'
# 📋 **Answer:**
#
#  **Supporting Evidence from Documents:**
# **1. Prescription** (Patient: Doctors Urgent Care, OCR: EasyOCR, Relevance: 0.438)
#    _Doctors Urgent Care Walk-In Clinic 4900 33rd Ave: N , St: Petersburg; FL 33710 Office (727) 520-7900 Fax (727) 526-9179 Age For Address Date R # % Substitytion Allowed Refills 0 1 1 -2 -3..._
# **2. Prescription** (Patient: isesa
# Heg
# Patient Name
# Corporate
# MRD, OCR: EasyOCR, Relevance: 0.436)
#    _Ltda HealthCare Global Enterptisesa Heg Patient Name Corporate MRD: No : Company Name: Consultant Name R LiPosomAL Ivj OR ' 2 xdaxlx Pitote ISAvu week 8 Name ol the Doctor: X ifyou Need above medicine..._
# **3. Prescription** (Patient: ION DEPARTMENT
# colukbub, OCR: EasyOCR, Relevance: 0.436)
#    _WALTON PHYSICIANS SUPPLY co. PRESCRIPTION DEPARTMENT colukbub: ohio EA "..._
#
# **Search Quality:** Average relevance score: 0.428
#
#  **Search Results:**
#     Document chunks found: 5
#     Average relevance score: 0.428
#     Knowledge graph used: Yes
#
# 📄 **Top Sources:**
#    1. Prescription (Patient: Doctors Urgent Care, Score: 0.438)
#    2. Prescription (Patient: isesa
# Heg
# Patient Name
# Corporate
# MRD, Score: 0.436)
#
#  **Enter your medical query:**
# 🔍 Query: give me the patient names u have
#
#  **Processing query #3...**
# ----------------------------------------
# 🔍 Processing query: 'give me the patient names u have'
# 📋 **Answer:**
#
#  **Supporting Evidence from Documents:**
# **1. Prescription** (Patient: isesa
# Heg
# Patient Name
# Corporate
# MRD, OCR: EasyOCR, Relevance: 0.593)
#    _Ltda HealthCare Global Enterptisesa Heg Patient Name Corporate MRD: No : Company Name: Consultant Name R LiPosomAL Ivj OR ' 2 xdaxlx Pitote ISAvu week 8 Name ol the Doctor: X ifyou Need above medicine..._
# **2. Prescription** (Patient: Jayaprakash Hebbar
# MBBS, OCR: EasyOCR, Relevance: 0.562)
#    _Dr: Jayaprakash Hebbar MBBS Reg: No. 2008/08/2976 Clinic 2642 Resi : 2642 4366 Palace. Hill Road, Mob:: 9820086992 49, Turner Road, Bandra; Mumbai - 400 050. SAT & SUN MORNING ONLY Er Zad Aoofaa T40, ..._
# **3. Lab_Report** (Patient: ID
# FH, OCR: EasyOCR, Relevance: 0.552)
#    _for this accession Dr.Sarvjot Kaur Sr.Consultant PERFORMED AT View Details View Report Agilus Diagnostics Ltd Bangalocet 5Gad Gurukrupa Layout; Opp: Fab Mall,Nagarbhavi Znd Bangalorc, 560072 Patient R..._
#
# **Search Quality:** Average relevance score: 0.559
#
#  **Search Results:**
#     Document chunks found: 5
#     Average relevance score: 0.559
#     Knowledge graph used: No
#
# 📄 **Top Sources:**
#    1. Prescription (Patient: isesa
# Heg
# Patient Name
# Corporate
# MRD, Score: 0.593)
#    2. Prescription (Patient: Jayaprakash Hebbar
# MBBS, Score: 0.562)
#
#  **Enter your medical query:**
# 🔍 Query: IC MR ASHWIN Patlent Last Patient Sample give me his history
#
#  **Processing query #4...**
# ----------------------------------------
# 🔍 Processing query: 'IC MR ASHWIN Patlent Last Patient Sample give me his history'
# 📋 **Answer:**
#
#  **Supporting Evidence from Documents:**
# **1. Lab_Report** (Patient: Associate Director, OCR: EasyOCR, Relevance: 0.476)
#    _Laboratory Investigation Report Patient] Centre Collection DatelTime : 26/Apr/2025 06.46PM Dr:Vyom Aggarwal Reporting DatelTime : 26/Apr/2025 08.32PM Hematology No:SB210688 Pa e Dr. Pooja Bhasin M.D: ..._
# **2. Prescription** (Patient: None, OCR: EasyOCR, Relevance: 0.462)
#    _Dr B, Who Farmstrcct 12 Kirkvillc tel, 3876 date R/ 1994 4 4 hrl Pahinf 30 Ms/Mr address;..._
# **3. Prescription** (Patient: Jayaprakash Hebbar
# MBBS, OCR: EasyOCR, Relevance: 0.454)
#    _Dr: Jayaprakash Hebbar MBBS Reg: No. 2008/08/2976 Clinic 2642 Resi : 2642 4366 Palace. Hill Road, Mob:: 9820086992 49, Turner Road, Bandra; Mumbai - 400 050. SAT & SUN MORNING ONLY Er Zad Aoofaa T40, ..._
#
# **Search Quality:** Average relevance score: 0.459
#
#  **Search Results:**
#     Document chunks found: 5
#     Average relevance score: 0.459
#     Knowledge graph used: Yes
#
# 📄 **Top Sources:**
#    1. Lab_Report (Patient: Associate Director, Score: 0.476)
#    2. Prescription (Patient: None, Score: 0.462)
#
#  **Enter your medical query:**
# 🔍 Query:    3. List all patients with their medical history
#
#  **Processing query #5...**
# ----------------------------------------
# 🔍 Processing query: '3. List all patients with their medical history'
# 📋 **Answer:**
#
#  **Supporting Evidence from Documents:**
# **1. Lab_Report** (Patient: REEE RANGE
# RESULTS
# COMPONENT, OCR: EasyOCR, Relevance: 0.421)
#    _OSCAR SUPER SPECIALITY HOSPITAL & TRAUMA CENTRE % Civil Hospital, Sonipat | Mob :] 42418 Transuctlon MRS RAKHI Date Patieni Nam Mobile No 4810 Reporting Date Doctor Nam CR.P (QUANTITATIVE) TTest Name ..._
# **2. Prescription** (Patient: Jsm nu slaik, OCR: EasyOCR, Relevance: 0.419)
#    _Jsm nu slaik Dr Mahesh Kumar Ruvoorl KIMS HOSPItALSI ning sd% @ % "nc dd Ibusnd olndt Mh Su 4 Mudl dn 4 W~L b Sn Mworm Olem Fess t M:" ehu 020 6j chuk Krishno Institute of Medical Sclences Limited 500..._
# **3. Lab_Report** (Patient: REFE RANGE
# COMPONEN
# RESULIS
# UNITS
# CRP, OCR: EasyOCR, Relevance: 0.409)
#    _OFCAR SUPER SPECIALITY HOSPITAL & TRAUMA CENTRE Ipp: Civil Hospital, Sonipat Mob : 42304 Transaction KUMAR GUPTA Paticnt Nam Date Mobile No " 4839 Doctor Nam Date CRP (QUANTITATIVE) Test Name REFE RAN..._
#
# **Search Quality:** Average relevance score: 0.412
#
#  **Search Results:**
#     Document chunks found: 5
#     Average relevance score: 0.412
#     Knowledge graph used: Yes
#
# 📄 **Top Sources:**
#    1. Lab_Report (Patient: REEE RANGE
# RESULTS
# COMPONENT, Score: 0.421)
#    2. Prescription (Patient: Jsm nu slaik, Score: 0.419)
#
#  **Enter your medical query:**
#
#
#  Session interrupted. Goodbye!
